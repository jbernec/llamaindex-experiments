# %% [markdown]
# ### Test LlamaParse library with Azure Blob Storage pdf data ingestion

# %%
from azure.keyvault.secrets import SecretClient
from azure.identity import DefaultAzureCredential
from llama_parse import LlamaParse
from llama_index.core.node_parser import MarkdownElementNodeParser
from llama_index.core.readers import SimpleDirectoryReader
import os


keyVaultName = os.environ["KEY_VAULT_NAME"]
KVUri = f"https://{keyVaultName}.vault.azure.net"

credential = DefaultAzureCredential()
client = SecretClient(vault_url=KVUri, credential=credential)
client.get_secret(name="aoai-endpoint").value
# base_url: str = 'https://api.cloud.llamaindex.ai'
parser = LlamaParse(
    result_type="markdown",
    parsing_instruction="This is an auto insurance claim document.",
    use_vendor_multimodal_model=True,
    vendor_multimodal_model_name= "openai-gpt-4o-mini",
    vendor_multimodal_api_key= client.get_secret(name="openai-apikey").value,
    api_key = client.get_secret(name="llamacloudkey").value
)

# %%
import nest_asyncio; nest_asyncio.apply()

file_path = "C:\\source\\github\\llamaparse\\insurance-claims-rag-data\\*.pdf"
CLAIMS_DIR = "insurance-claims-rag-data"


def get_claims_files(claims_dir=CLAIMS_DIR) -> list[str]:
    files = []
    for f in os.listdir(claims_dir):
        fname = os.path.join(claims_dir, f)
        if os.path.isfile(fname):
            files.append(fname)
    return files
files = get_claims_files()  # get all files from the claims/ directory

# %%
files
# Out:
# ['insurance-claims-rag-data\\claim_1.pdf',
#  'insurance-claims-rag-data\\claim_2.pdf',
#  'insurance-claims-rag-data\\claim_3.pdf',
#  'insurance-claims-rag-data\\claim_4.pdf',
#  'insurance-claims-rag-data\\claim_5.pdf']

# %%
md_json_objs = parser.get_json_result(
    files
)  # extract markdown data for insurance claim document
# Out:
# Parsing files:   0%|          | 0/5 [00:00<?, ?it/s]
# Started parsing the file under job_id 30277837-ac7f-4437-a716-8733f1cc5c8b
# Started parsing the file under job_id 4ab8a70d-6a74-4540-9158-329cc1f2ddcf
# Started parsing the file under job_id d2b2f6b5-05e7-4517-9f13-ec7871aeaa0a
# Started parsing the file under job_id 6f60648e-c044-4feb-a402-bc11116f5d07
# Parsing files:  20%|██        | 1/5 [00:08<00:34,  8.74s/it]
# Started parsing the file under job_id 6c23082f-8b5c-4e1c-924a-24e682d7f824
# Parsing files: 100%|██████████| 5/5 [00:11<00:00,  2.36s/it]

# %%
md_json_objs
# Out:
# [{'pages': [{'page': 1,
#     'md': '# Auto Claims\n\nIn the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.  \n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.  \n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#     'images': [{'name': 'page-0.jpg',
#       'height': 0,
#       'width': 0,
#       'x': 0,
#       'y': 0,
#       'type': 'full_page_screenshot'}],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'Auto Claims',
#       'md': '# Auto Claims'},
#      {'type': 'text',
#       'value': 'In the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.  \n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.  \n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#       'md': 'In the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.  \n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.  \n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.'}]},
#    {'page': 2,
#     'md': '\n# AUTOMOBILE CLAIM\n\n## LOSS\n- **Date:** 06/23/2023\n- **Location:** Intersection of Vine Street and Sunset Bl\n- **City:** Los Angeles\n- **State:** CA\n- **Police Dept. Involved:** LAPD\n- **Ticket Issued:** Traffic Violation\n\n## DESCRIPTION OF ACCIDENT\nOn October 15, 2023, at approximately 3:30 PM, I was driving my 2020 Honda Accord (License Plate: 7XYZ123) southbound on Vine St.\n\n## INSURED VEHICLE\n- **Year:** 2020\n- **Make:** Honda\n- **Model:** Accord\n- **V.I.N.:** 1HGCV1F30LA123456\n- **Plate:** 7XYZ123\n- **Extent of Damages:** The front passenger side of my Honda Accord sustained significant damage, including a demolished door and broken headlights. Estimated repair cost: $3,500.\n- **Driver:** Michael Johnson\n- **Date of Birth:** 01/15/1985\n- **License No.:** 1111111111\n- **State:** CA\n\n## OTHER VEHICLE\n- **Year:** 2018\n- **Make:** Ford\n- **Model:** Escape\n- **Owner:** Sarah Brown\n- **Phone:** 2139876543\n- **Extent of Damages:** The Ford Escape had damage to the front bumper and hood. Estimated repair cost: $2,000.\n- **Address:** 405 Hilgard Av\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90095\n\n## INSURANCE INFORMATION\n- **Company Name:** Morts Mutual Insurance\n- **Policy No.:** 987654321\n- **Agent Name:** Emily Carter\n- **Phone:** 2131234567\n\n## INJURED\n- **Name:** Michael Johnson\n- **Phone:** 3101234567\n- **Address:** 3470 Trousdale Pkwy\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90089\n- **Extent of Injury:** I sustained minor injuries, including neck pain and a bruise on my left arm. I sought medical attention at the local urgent care facility.\n\n## WITNESSES\n- **Name:** David Thompson\n- **Phone:** 3105678901\n- **Address:** 633 W 5th St\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90071\n\n## IMPACT\n- **Is damaged auto essential to business?** No\n- **How?** \n',
#     'images': [{'name': 'page-1.jpg',
#       'height': 0,
#       'width': 0,
#       'x': 0,
#       'y': 0,
#       'type': 'full_page_screenshot'}],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'AUTOMOBILE CLAIM',
#       'md': '# AUTOMOBILE CLAIM'},
#      {'type': 'heading', 'lvl': 2, 'value': 'LOSS', 'md': '## LOSS'},
#      {'type': 'text',
#       'value': '- **Date:** 06/23/2023\n- **Location:** Intersection of Vine Street and Sunset Bl\n- **City:** Los Angeles\n- **State:** CA\n- **Police Dept. Involved:** LAPD\n- **Ticket Issued:** Traffic Violation',
#       'md': '- **Date:** 06/23/2023\n- **Location:** Intersection of Vine Street and Sunset Bl\n- **City:** Los Angeles\n- **State:** CA\n- **Police Dept. Involved:** LAPD\n- **Ticket Issued:** Traffic Violation'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'DESCRIPTION OF ACCIDENT',
#       'md': '## DESCRIPTION OF ACCIDENT'},
#      {'type': 'text',
#       'value': 'On October 15, 2023, at approximately 3:30 PM, I was driving my 2020 Honda Accord (License Plate: 7XYZ123) southbound on Vine St.',
#       'md': 'On October 15, 2023, at approximately 3:30 PM, I was driving my 2020 Honda Accord (License Plate: 7XYZ123) southbound on Vine St.'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'INSURED VEHICLE',
#       'md': '## INSURED VEHICLE'},
#      {'type': 'text',
#       'value': '- **Year:** 2020\n- **Make:** Honda\n- **Model:** Accord\n- **V.I.N.:** 1HGCV1F30LA123456\n- **Plate:** 7XYZ123\n- **Extent of Damages:** The front passenger side of my Honda Accord sustained significant damage, including a demolished door and broken headlights. Estimated repair cost: $3,500.\n- **Driver:** Michael Johnson\n- **Date of Birth:** 01/15/1985\n- **License No.:** 1111111111\n- **State:** CA',
#       'md': '- **Year:** 2020\n- **Make:** Honda\n- **Model:** Accord\n- **V.I.N.:** 1HGCV1F30LA123456\n- **Plate:** 7XYZ123\n- **Extent of Damages:** The front passenger side of my Honda Accord sustained significant damage, including a demolished door and broken headlights. Estimated repair cost: $3,500.\n- **Driver:** Michael Johnson\n- **Date of Birth:** 01/15/1985\n- **License No.:** 1111111111\n- **State:** CA'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'OTHER VEHICLE',
#       'md': '## OTHER VEHICLE'},
#      {'type': 'text',
#       'value': '- **Year:** 2018\n- **Make:** Ford\n- **Model:** Escape\n- **Owner:** Sarah Brown\n- **Phone:** 2139876543\n- **Extent of Damages:** The Ford Escape had damage to the front bumper and hood. Estimated repair cost: $2,000.\n- **Address:** 405 Hilgard Av\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90095',
#       'md': '- **Year:** 2018\n- **Make:** Ford\n- **Model:** Escape\n- **Owner:** Sarah Brown\n- **Phone:** 2139876543\n- **Extent of Damages:** The Ford Escape had damage to the front bumper and hood. Estimated repair cost: $2,000.\n- **Address:** 405 Hilgard Av\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90095'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'INSURANCE INFORMATION',
#       'md': '## INSURANCE INFORMATION'},
#      {'type': 'text',
#       'value': '- **Company Name:** Morts Mutual Insurance\n- **Policy No.:** 987654321\n- **Agent Name:** Emily Carter\n- **Phone:** 2131234567',
#       'md': '- **Company Name:** Morts Mutual Insurance\n- **Policy No.:** 987654321\n- **Agent Name:** Emily Carter\n- **Phone:** 2131234567'},
#      {'type': 'heading', 'lvl': 2, 'value': 'INJURED', 'md': '## INJURED'},
#      {'type': 'text',
#       'value': '- **Name:** Michael Johnson\n- **Phone:** 3101234567\n- **Address:** 3470 Trousdale Pkwy\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90089\n- **Extent of Injury:** I sustained minor injuries, including neck pain and a bruise on my left arm. I sought medical attention at the local urgent care facility.',
#       'md': '- **Name:** Michael Johnson\n- **Phone:** 3101234567\n- **Address:** 3470 Trousdale Pkwy\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90089\n- **Extent of Injury:** I sustained minor injuries, including neck pain and a bruise on my left arm. I sought medical attention at the local urgent care facility.'},
#      {'type': 'heading', 'lvl': 2, 'value': 'WITNESSES', 'md': '## WITNESSES'},
#      {'type': 'text',
#       'value': '- **Name:** David Thompson\n- **Phone:** 3105678901\n- **Address:** 633 W 5th St\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90071',
#       'md': '- **Name:** David Thompson\n- **Phone:** 3105678901\n- **Address:** 633 W 5th St\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90071'},
#      {'type': 'heading', 'lvl': 2, 'value': 'IMPACT', 'md': '## IMPACT'},
#      {'type': 'text',
#       'value': '- **Is damaged auto essential to business?** No\n- **How?**',
#       'md': '- **Is damaged auto essential to business?** No\n- **How?**'}]},
#    {'page': 3,
#     'md': '# INSTRUCTIONS TO INSURED:\n\n## If still on the scene:\n1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.\n\n## If not on the scene:\n1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.',
#     'images': [{'name': 'page-2.jpg',
#       'height': 0,
#       'width': 0,
#       'x': 0,
#       'y': 0,
#       'type': 'full_page_screenshot'}],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'INSTRUCTIONS TO INSURED:',
#       'md': '# INSTRUCTIONS TO INSURED:'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'If still on the scene:',
#       'md': '## If still on the scene:'},
#      {'type': 'text',
#       'value': '1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.',
#       'md': '1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'If not on the scene:',
#       'md': '## If not on the scene:'},
#      {'type': 'text',
#       'value': '1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.',
#       'md': '1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.'}]}],
#   'job_metadata': {'credits_used': 0.0,
#    'job_credits_usage': 0,
#    'job_pages': 0,
#    'job_is_cache_hit': True,
#    'credits_max': 1000},
#   'job_id': '6c23082f-8b5c-4e1c-924a-24e682d7f824',
#   'file_path': 'insurance-claims-rag-data\\claim_1.pdf'},
#  {'pages': [{'page': 1,
#     'md': '# Auto Claims\n\n## In the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.  \n\n## In the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.  \n\n## After we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#     'images': [{'name': 'page-0.jpg',
#       'height': 0,
#       'width': 0,
#       'x': 0,
#       'y': 0,
#       'type': 'full_page_screenshot'}],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'Auto Claims',
#       'md': '# Auto Claims'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'In the event of an automobile accident:',
#       'md': '## In the event of an automobile accident:'},
#      {'type': 'text',
#       'value': '1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.',
#       'md': '1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'In the event of a windshield, vandalism or theft loss:',
#       'md': '## In the event of a windshield, vandalism or theft loss:'},
#      {'type': 'text',
#       'value': '1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.',
#       'md': '1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'After we report the claim to the insurance company, the claims adjuster will:',
#       'md': '## After we report the claim to the insurance company, the claims adjuster will:'},
#      {'type': 'text',
#       'value': '1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#       'md': '1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.'}]},
#    {'page': 2,
#     'md': '\n# AUTOMOBILE CLAIM\n\n## LOSS\n- **Date:** 10/15/2023\n- **Location:** Intersection of 5th Ave and Elm St\n- **City:** Chicago\n- **State:** IL\n- **Police Dept. Involved:** CPD\n- **Ticket Issued:** Traffic Violation Ticket\n\n## DESCRIPTION OF ACCIDENT\nI was traveling north on 5th Ave when the other vehicle, which was traveling east on Elm St, failed to stop at a red light and collided with the front passenger side of my vehicle. The impact caused significant damage to my car and minor injuries to me.\n\n## INSURED VEHICLE\n- **Year:** 2020\n- **Make:** Honda\n- **Model:** Accord\n- **V.I.N.:** 1HGCV1F30LA123456\n- **Plate:** XYZ 1234\n- **Extent of Damages:** Front bumper, hood, fenders, head/tailights, windshield, doors\n- **Driver:** John Doe\n- **Date of Birth:** January 15, 1985\n- **License No.:** ABC123456\n- **State:** IL\n\n## OTHER VEHICLE\n- **Year:** 2018\n- **Make:** Ford\n- **Model:** F-150\n- **Owner:** Michael Green\n- **Phone:** 3129999999\n- **Address:** 321 Main St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601\n\n## INSURANCE INFORMATION\n- **Company Name:** XYZ Insurance\n- **Policy No.:** 987654321\n- **Agent Name:** \n- **Phone:** \n\n## INJURED\n- **Name:** John Doe\n- **Phone:** (555) 123-4567\n- **Address:** 123 Main St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601\n- **Extent of Injury:** Whiplash and bruising on the right arm\n\n## WITNESSES\n- **Name:** Jane Smith\n- **Phone:** (555) 987-6543\n- **Address:** 123 Market St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601\n\n## IMPACT\n- **Is damaged auto essential to business?** No\n- **How?**\n',
#     'images': [{'name': 'page-1.jpg',
#       'height': 0,
#       'width': 0,
#       'x': 0,
#       'y': 0,
#       'type': 'full_page_screenshot'}],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'AUTOMOBILE CLAIM',
#       'md': '# AUTOMOBILE CLAIM'},
#      {'type': 'heading', 'lvl': 2, 'value': 'LOSS', 'md': '## LOSS'},
#      {'type': 'text',
#       'value': '- **Date:** 10/15/2023\n- **Location:** Intersection of 5th Ave and Elm St\n- **City:** Chicago\n- **State:** IL\n- **Police Dept. Involved:** CPD\n- **Ticket Issued:** Traffic Violation Ticket',
#       'md': '- **Date:** 10/15/2023\n- **Location:** Intersection of 5th Ave and Elm St\n- **City:** Chicago\n- **State:** IL\n- **Police Dept. Involved:** CPD\n- **Ticket Issued:** Traffic Violation Ticket'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'DESCRIPTION OF ACCIDENT',
#       'md': '## DESCRIPTION OF ACCIDENT'},
#      {'type': 'text',
#       'value': 'I was traveling north on 5th Ave when the other vehicle, which was traveling east on Elm St, failed to stop at a red light and collided with the front passenger side of my vehicle. The impact caused significant damage to my car and minor injuries to me.',
#       'md': 'I was traveling north on 5th Ave when the other vehicle, which was traveling east on Elm St, failed to stop at a red light and collided with the front passenger side of my vehicle. The impact caused significant damage to my car and minor injuries to me.'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'INSURED VEHICLE',
#       'md': '## INSURED VEHICLE'},
#      {'type': 'text',
#       'value': '- **Year:** 2020\n- **Make:** Honda\n- **Model:** Accord\n- **V.I.N.:** 1HGCV1F30LA123456\n- **Plate:** XYZ 1234\n- **Extent of Damages:** Front bumper, hood, fenders, head/tailights, windshield, doors\n- **Driver:** John Doe\n- **Date of Birth:** January 15, 1985\n- **License No.:** ABC123456\n- **State:** IL',
#       'md': '- **Year:** 2020\n- **Make:** Honda\n- **Model:** Accord\n- **V.I.N.:** 1HGCV1F30LA123456\n- **Plate:** XYZ 1234\n- **Extent of Damages:** Front bumper, hood, fenders, head/tailights, windshield, doors\n- **Driver:** John Doe\n- **Date of Birth:** January 15, 1985\n- **License No.:** ABC123456\n- **State:** IL'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'OTHER VEHICLE',
#       'md': '## OTHER VEHICLE'},
#      {'type': 'text',
#       'value': '- **Year:** 2018\n- **Make:** Ford\n- **Model:** F-150\n- **Owner:** Michael Green\n- **Phone:** 3129999999\n- **Address:** 321 Main St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601',
#       'md': '- **Year:** 2018\n- **Make:** Ford\n- **Model:** F-150\n- **Owner:** Michael Green\n- **Phone:** 3129999999\n- **Address:** 321 Main St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'INSURANCE INFORMATION',
#       'md': '## INSURANCE INFORMATION'},
#      {'type': 'text',
#       'value': '- **Company Name:** XYZ Insurance\n- **Policy No.:** 987654321\n- **Agent Name:** \n- **Phone:**',
#       'md': '- **Company Name:** XYZ Insurance\n- **Policy No.:** 987654321\n- **Agent Name:** \n- **Phone:**'},
#      {'type': 'heading', 'lvl': 2, 'value': 'INJURED', 'md': '## INJURED'},
#      {'type': 'text',
#       'value': '- **Name:** John Doe\n- **Phone:** (555) 123-4567\n- **Address:** 123 Main St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601\n- **Extent of Injury:** Whiplash and bruising on the right arm',
#       'md': '- **Name:** John Doe\n- **Phone:** (555) 123-4567\n- **Address:** 123 Main St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601\n- **Extent of Injury:** Whiplash and bruising on the right arm'},
#      {'type': 'heading', 'lvl': 2, 'value': 'WITNESSES', 'md': '## WITNESSES'},
#      {'type': 'text',
#       'value': '- **Name:** Jane Smith\n- **Phone:** (555) 987-6543\n- **Address:** 123 Market St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601',
#       'md': '- **Name:** Jane Smith\n- **Phone:** (555) 987-6543\n- **Address:** 123 Market St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601'},
#      {'type': 'heading', 'lvl': 2, 'value': 'IMPACT', 'md': '## IMPACT'},
#      {'type': 'text',
#       'value': '- **Is damaged auto essential to business?** No\n- **How?**',
#       'md': '- **Is damaged auto essential to business?** No\n- **How?**'}]},
#    {'page': 3,
#     'md': '# INSTRUCTIONS TO INSURED:\n\n## If still on the scene:\n1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.\n\n## If not on the scene:\n1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.',
#     'images': [{'name': 'page-2.jpg',
#       'height': 0,
#       'width': 0,
#       'x': 0,
#       'y': 0,
#       'type': 'full_page_screenshot'}],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'INSTRUCTIONS TO INSURED:',
#       'md': '# INSTRUCTIONS TO INSURED:'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'If still on the scene:',
#       'md': '## If still on the scene:'},
#      {'type': 'text',
#       'value': '1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.',
#       'md': '1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'If not on the scene:',
#       'md': '## If not on the scene:'},
#      {'type': 'text',
#       'value': '1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.',
#       'md': '1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.'}]}],
#   'job_metadata': {'credits_used': 0.0,
#    'job_credits_usage': 0,
#    'job_pages': 0,
#    'job_is_cache_hit': True,
#    'credits_max': 1000},
#   'job_id': '6f60648e-c044-4feb-a402-bc11116f5d07',
#   'file_path': 'insurance-claims-rag-data\\claim_2.pdf'},
#  {'pages': [{'page': 1,
#     'md': '# Auto Claims\n\nIn the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.  \n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.  \n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#     'images': [{'name': 'page-0.jpg',
#       'height': 0,
#       'width': 0,
#       'x': 0,
#       'y': 0,
#       'type': 'full_page_screenshot'}],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'Auto Claims',
#       'md': '# Auto Claims'},
#      {'type': 'text',
#       'value': 'In the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.  \n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.  \n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#       'md': 'In the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.  \n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.  \n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.'}]},
#    {'page': 2,
#     'md': "\n# AUTOMOBILE CLAIM\n\n## LOSS\n- **Date:** 03/10/2023\n- **Location:** Intersection of Main St and Oak St\n- **City:** Boise\n- **State:** ID\n- **Police Dept. Involved:** Boise Police Department\n- **Ticket Issued:** \n\n## DESCRIPTION OF ACCIDENT\nOn March 10, 2023, at approximately 9:15 AM, I was heading north at a parking space in the Boise Towne Square Mall parking lot. As I checked my mirrors and blind spots, I did not see any vehicles approaching. However, the driver of Vehicle 2, Michael Chen, was driving too fast through the parking lot and failed to stop in time. This resulted in my vehicle sustaining damages to the rear bumper and trunk.\n\n## INSURED VEHICLE\n- **Year:** 2018\n- **Make:** Toyota\n- **Model:** Camry\n- **V.I.N.:** 4T1BF1FK8JU01234\n- **Plate:** GH789\n- **Extent of Damages:** Rear bumper and trunk damage, including scratches, dents, and broken taillight\n- **Driver:** Rachel Patel (ASK IF OFFICER OF CO)\n- **Date of Birth:** February 12, 1992\n- **License No.:** ID1234567\n\n## OTHER VEHICLE\n- **Year:** 2020\n- **Make:** Ford\n- **Model:** F-150\n- **Owner:** Michael Chen\n- **Phone:** 5559999999\n- **Address:** 303 Maple Avenue\n- **City:** Boise\n- **State:** ID\n- **Zip:** 83701\n\n## Insurance Information\n- **Company Name:** XYZ Insurance Company\n- **Policy No.:** 987654321\n- **Agent Name:** Michael Hawk\n- **Phone:** 2135672349\n\n## INJURED\n- **Name:** \n- **Phone:** \n- **Address:** \n- **City:** \n- **State:** \n- **Zip:** \n- **Extent of Injury:** \n\n## WITNESSES\n- **Name:** Sophia Rodriguez\n- **Phone:** 5554567890\n- **Address:** 2557 La Cienega Boulevard\n- **City:** Boise\n- **State:** ID\n- **Zip:** 83701\n\n## IMPACT\n- **Is damaged auto essential to business?** Yes\n- **How?** Rachel can't drive to work anymore.\n",
#     'images': [{'name': 'page-1.jpg',
#       'height': 0,
#       'width': 0,
#       'x': 0,
#       'y': 0,
#       'type': 'full_page_screenshot'}],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'AUTOMOBILE CLAIM',
#       'md': '# AUTOMOBILE CLAIM'},
#      {'type': 'heading', 'lvl': 2, 'value': 'LOSS', 'md': '## LOSS'},
#      {'type': 'text',
#       'value': '- **Date:** 03/10/2023\n- **Location:** Intersection of Main St and Oak St\n- **City:** Boise\n- **State:** ID\n- **Police Dept. Involved:** Boise Police Department\n- **Ticket Issued:**',
#       'md': '- **Date:** 03/10/2023\n- **Location:** Intersection of Main St and Oak St\n- **City:** Boise\n- **State:** ID\n- **Police Dept. Involved:** Boise Police Department\n- **Ticket Issued:**'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'DESCRIPTION OF ACCIDENT',
#       'md': '## DESCRIPTION OF ACCIDENT'},
#      {'type': 'text',
#       'value': 'On March 10, 2023, at approximately 9:15 AM, I was heading north at a parking space in the Boise Towne Square Mall parking lot. As I checked my mirrors and blind spots, I did not see any vehicles approaching. However, the driver of Vehicle 2, Michael Chen, was driving too fast through the parking lot and failed to stop in time. This resulted in my vehicle sustaining damages to the rear bumper and trunk.',
#       'md': 'On March 10, 2023, at approximately 9:15 AM, I was heading north at a parking space in the Boise Towne Square Mall parking lot. As I checked my mirrors and blind spots, I did not see any vehicles approaching. However, the driver of Vehicle 2, Michael Chen, was driving too fast through the parking lot and failed to stop in time. This resulted in my vehicle sustaining damages to the rear bumper and trunk.'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'INSURED VEHICLE',
#       'md': '## INSURED VEHICLE'},
#      {'type': 'text',
#       'value': '- **Year:** 2018\n- **Make:** Toyota\n- **Model:** Camry\n- **V.I.N.:** 4T1BF1FK8JU01234\n- **Plate:** GH789\n- **Extent of Damages:** Rear bumper and trunk damage, including scratches, dents, and broken taillight\n- **Driver:** Rachel Patel (ASK IF OFFICER OF CO)\n- **Date of Birth:** February 12, 1992\n- **License No.:** ID1234567',
#       'md': '- **Year:** 2018\n- **Make:** Toyota\n- **Model:** Camry\n- **V.I.N.:** 4T1BF1FK8JU01234\n- **Plate:** GH789\n- **Extent of Damages:** Rear bumper and trunk damage, including scratches, dents, and broken taillight\n- **Driver:** Rachel Patel (ASK IF OFFICER OF CO)\n- **Date of Birth:** February 12, 1992\n- **License No.:** ID1234567'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'OTHER VEHICLE',
#       'md': '## OTHER VEHICLE'},
#      {'type': 'text',
#       'value': '- **Year:** 2020\n- **Make:** Ford\n- **Model:** F-150\n- **Owner:** Michael Chen\n- **Phone:** 5559999999\n- **Address:** 303 Maple Avenue\n- **City:** Boise\n- **State:** ID\n- **Zip:** 83701',
#       'md': '- **Year:** 2020\n- **Make:** Ford\n- **Model:** F-150\n- **Owner:** Michael Chen\n- **Phone:** 5559999999\n- **Address:** 303 Maple Avenue\n- **City:** Boise\n- **State:** ID\n- **Zip:** 83701'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'Insurance Information',
#       'md': '## Insurance Information'},
#      {'type': 'text',
#       'value': '- **Company Name:** XYZ Insurance Company\n- **Policy No.:** 987654321\n- **Agent Name:** Michael Hawk\n- **Phone:** 2135672349',
#       'md': '- **Company Name:** XYZ Insurance Company\n- **Policy No.:** 987654321\n- **Agent Name:** Michael Hawk\n- **Phone:** 2135672349'},
#      {'type': 'heading', 'lvl': 2, 'value': 'INJURED', 'md': '## INJURED'},
#      {'type': 'text',
#       'value': '- **Name:** \n- **Phone:** \n- **Address:** \n- **City:** \n- **State:** \n- **Zip:** \n- **Extent of Injury:**',
#       'md': '- **Name:** \n- **Phone:** \n- **Address:** \n- **City:** \n- **State:** \n- **Zip:** \n- **Extent of Injury:**'},
#      {'type': 'heading', 'lvl': 2, 'value': 'WITNESSES', 'md': '## WITNESSES'},
#      {'type': 'text',
#       'value': '- **Name:** Sophia Rodriguez\n- **Phone:** 5554567890\n- **Address:** 2557 La Cienega Boulevard\n- **City:** Boise\n- **State:** ID\n- **Zip:** 83701',
#       'md': '- **Name:** Sophia Rodriguez\n- **Phone:** 5554567890\n- **Address:** 2557 La Cienega Boulevard\n- **City:** Boise\n- **State:** ID\n- **Zip:** 83701'},
#      {'type': 'heading', 'lvl': 2, 'value': 'IMPACT', 'md': '## IMPACT'},
#      {'type': 'text',
#       'value': "- **Is damaged auto essential to business?** Yes\n- **How?** Rachel can't drive to work anymore.",
#       'md': "- **Is damaged auto essential to business?** Yes\n- **How?** Rachel can't drive to work anymore."}]},
#    {'page': 3,
#     'md': '# INSTRUCTIONS TO INSURED:\n\n## If still on the scene:\n1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.\n\n## If not on the scene:\n1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.',
#     'images': [{'name': 'page-2.jpg',
#       'height': 0,
#       'width': 0,
#       'x': 0,
#       'y': 0,
#       'type': 'full_page_screenshot'}],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'INSTRUCTIONS TO INSURED:',
#       'md': '# INSTRUCTIONS TO INSURED:'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'If still on the scene:',
#       'md': '## If still on the scene:'},
#      {'type': 'text',
#       'value': '1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.',
#       'md': '1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'If not on the scene:',
#       'md': '## If not on the scene:'},
#      {'type': 'text',
#       'value': '1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.',
#       'md': '1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.'}]}],
#   'job_metadata': {'credits_used': 0.0,
#    'job_credits_usage': 0,
#    'job_pages': 0,
#    'job_is_cache_hit': True,
#    'credits_max': 1000},
#   'job_id': '30277837-ac7f-4437-a716-8733f1cc5c8b',
#   'file_path': 'insurance-claims-rag-data\\claim_3.pdf'},
#  {'pages': [{'page': 1,
#     'md': '# Auto Claims\n\n## In the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.\n4. Call us to report the accident.\n\n## In the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.\n2. Call us to report a loss.\n\n## After we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates.\n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged.\n3. Contact you for a settlement.\n4. Deal directly with the others involved in the accident.\n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.\n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#     'images': [{'name': 'page-0.jpg',
#       'height': 0,
#       'width': 0,
#       'x': 0,
#       'y': 0,
#       'type': 'full_page_screenshot'}],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'Auto Claims',
#       'md': '# Auto Claims'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'In the event of an automobile accident:',
#       'md': '## In the event of an automobile accident:'},
#      {'type': 'text',
#       'value': '1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.\n4. Call us to report the accident.',
#       'md': '1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.\n4. Call us to report the accident.'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'In the event of a windshield, vandalism or theft loss:',
#       'md': '## In the event of a windshield, vandalism or theft loss:'},
#      {'type': 'text',
#       'value': '1. Report the vandalism loss or theft to the police.\n2. Call us to report a loss.',
#       'md': '1. Report the vandalism loss or theft to the police.\n2. Call us to report a loss.'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'After we report the claim to the insurance company, the claims adjuster will:',
#       'md': '## After we report the claim to the insurance company, the claims adjuster will:'},
#      {'type': 'text',
#       'value': '1. Contact you to request details of the accident and repair estimates.\n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged.\n3. Contact you for a settlement.\n4. Deal directly with the others involved in the accident.\n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.\n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#       'md': '1. Contact you to request details of the accident and repair estimates.\n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged.\n3. Contact you for a settlement.\n4. Deal directly with the others involved in the accident.\n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.\n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.'}]},
#    {'page': 2,
# ...
#       'md': '1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.'}]}],
#   'job_metadata': {'credits_used': 0.0,
#    'job_credits_usage': 0,
#    'job_pages': 0,
#    'job_is_cache_hit': True,
#    'credits_max': 1000},
#   'job_id': '4ab8a70d-6a74-4540-9158-329cc1f2ddcf',
#   'file_path': 'insurance-claims-rag-data\\claim_4.pdf'},
#  {'pages': [{'page': 1,
#     'md': '# Auto Claims\n\nIn the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.\n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.\n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.\n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#     'images': [{'name': 'page-0.jpg',
#       'height': 0,
#       'width': 0,
#       'x': 0,
#       'y': 0,
#       'type': 'full_page_screenshot'}],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'Auto Claims',
#       'md': '# Auto Claims'},
#      {'type': 'text',
#       'value': 'In the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.\n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.\n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.\n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#       'md': 'In the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.\n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.\n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.\n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.'}]},
#    {'page': 2,
#     'md': '# AUTOMOBILE CLAIM\n\n## LOSS\n- **Date:** October 10, 2023  \n- **Location:** Lombard Street  \n- **City:** San Francisco  \n- **State:** CA  \n- **Police Dept. Involved:** SFPD  \n- **Ticket Issued:** Traffic Violation  \n\n## DESCRIPTION OF ACCIDENT\nOn the morning of October 10, 2023, I was driving my Honda Civic License Plate: 7ABC123 down Lombard Street in San Francisco. The weather was foggy and traffic was moving slowly due to congestion. As I approached an intersection, I tried gently to maintain a safe distance from the vehicle in front of me. Suddenly, I felt a bump as Jackson Johnson, who was doing a delivery on Leavenworth Street, collided with the rear of my vehicle. The impact caused damage to the rear bumper and trunk only. I was wearing my seatbelt and did not sustain any injuries. Mark asked me whether to check on me, and we exchanged insurance information. I have attached a copy of the police report, which was filed at the scene, along with photographs of the damage to both vehicles.\n\n## INSURED VEHICLE\n- **Year:** 2010  \n- **Make:** Honda  \n- **Model:** Civic  \n- **V.I.N.:** 1HGCM82633A123456  \n- **Plate:** 7ABC123  \n- **Extent of Damages:** Damage to rear bumper, Scratches on trunk  \n- **Driver:** Emily Rodriguez  \n  - **Date of Birth:** March 15, 1991  \n  - **License No.:** D123456789  \n  - **State:** CA  \n\n## OTHER VEHICLE\n- **Year:** 2020  \n- **Make:** Ford  \n- **Model:** Transit 250  \n- **Owner:** Mark Johnson  \n- **Phone:** 415202020  \n- **Address:** 305 Leavenworth Street  \n- **City:** San Francisco  \n- **State:** CA  \n- **Zip:** 94109  \n- **Insurance Information:**  \n  - **Company Name:** XYZ Insurance  \n  - **Policy No.:** 987654321  \n  - **Agent Name:** Lisa Carter  \n  - **Phone:** (415) 555-9876  \n\n## INJURED\n- **Name:**  \n- **Phone:**  \n- **Address:**  \n- **City:**  \n- **State:**  \n- **Zip:**  \n- **Extent of Injury:**  \n\n## WITNESSES\n- **Name:** Mia Chen  \n- **Phone:** (415) 555-5678  \n- **Address:** 5678 Beach St  \n- **City:** San Francisco  \n- **State:** CA  \n- **Zip:** 94123  \n\n## IMPACT\n- **Is damaged auto essential to business?** No  \n- **How?**  ',
#     'images': [{'name': 'page-1.jpg',
#       'height': 0,
#       'width': 0,
#       'x': 0,
#       'y': 0,
#       'type': 'full_page_screenshot'}],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'AUTOMOBILE CLAIM',
#       'md': '# AUTOMOBILE CLAIM'},
#      {'type': 'heading', 'lvl': 2, 'value': 'LOSS', 'md': '## LOSS'},
#      {'type': 'text',
#       'value': '- **Date:** October 10, 2023  \n- **Location:** Lombard Street  \n- **City:** San Francisco  \n- **State:** CA  \n- **Police Dept. Involved:** SFPD  \n- **Ticket Issued:** Traffic Violation',
#       'md': '- **Date:** October 10, 2023  \n- **Location:** Lombard Street  \n- **City:** San Francisco  \n- **State:** CA  \n- **Police Dept. Involved:** SFPD  \n- **Ticket Issued:** Traffic Violation'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'DESCRIPTION OF ACCIDENT',
#       'md': '## DESCRIPTION OF ACCIDENT'},
#      {'type': 'text',
#       'value': 'On the morning of October 10, 2023, I was driving my Honda Civic License Plate: 7ABC123 down Lombard Street in San Francisco. The weather was foggy and traffic was moving slowly due to congestion. As I approached an intersection, I tried gently to maintain a safe distance from the vehicle in front of me. Suddenly, I felt a bump as Jackson Johnson, who was doing a delivery on Leavenworth Street, collided with the rear of my vehicle. The impact caused damage to the rear bumper and trunk only. I was wearing my seatbelt and did not sustain any injuries. Mark asked me whether to check on me, and we exchanged insurance information. I have attached a copy of the police report, which was filed at the scene, along with photographs of the damage to both vehicles.',
#       'md': 'On the morning of October 10, 2023, I was driving my Honda Civic License Plate: 7ABC123 down Lombard Street in San Francisco. The weather was foggy and traffic was moving slowly due to congestion. As I approached an intersection, I tried gently to maintain a safe distance from the vehicle in front of me. Suddenly, I felt a bump as Jackson Johnson, who was doing a delivery on Leavenworth Street, collided with the rear of my vehicle. The impact caused damage to the rear bumper and trunk only. I was wearing my seatbelt and did not sustain any injuries. Mark asked me whether to check on me, and we exchanged insurance information. I have attached a copy of the police report, which was filed at the scene, along with photographs of the damage to both vehicles.'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'INSURED VEHICLE',
#       'md': '## INSURED VEHICLE'},
#      {'type': 'text',
#       'value': '- **Year:** 2010  \n- **Make:** Honda  \n- **Model:** Civic  \n- **V.I.N.:** 1HGCM82633A123456  \n- **Plate:** 7ABC123  \n- **Extent of Damages:** Damage to rear bumper, Scratches on trunk  \n- **Driver:** Emily Rodriguez  \n  - **Date of Birth:** March 15, 1991  \n  - **License No.:** D123456789  \n  - **State:** CA',
#       'md': '- **Year:** 2010  \n- **Make:** Honda  \n- **Model:** Civic  \n- **V.I.N.:** 1HGCM82633A123456  \n- **Plate:** 7ABC123  \n- **Extent of Damages:** Damage to rear bumper, Scratches on trunk  \n- **Driver:** Emily Rodriguez  \n  - **Date of Birth:** March 15, 1991  \n  - **License No.:** D123456789  \n  - **State:** CA'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'OTHER VEHICLE',
#       'md': '## OTHER VEHICLE'},
#      {'type': 'text',
#       'value': '- **Year:** 2020  \n- **Make:** Ford  \n- **Model:** Transit 250  \n- **Owner:** Mark Johnson  \n- **Phone:** 415202020  \n- **Address:** 305 Leavenworth Street  \n- **City:** San Francisco  \n- **State:** CA  \n- **Zip:** 94109  \n- **Insurance Information:**  \n  - **Company Name:** XYZ Insurance  \n  - **Policy No.:** 987654321  \n  - **Agent Name:** Lisa Carter  \n  - **Phone:** (415) 555-9876',
#       'md': '- **Year:** 2020  \n- **Make:** Ford  \n- **Model:** Transit 250  \n- **Owner:** Mark Johnson  \n- **Phone:** 415202020  \n- **Address:** 305 Leavenworth Street  \n- **City:** San Francisco  \n- **State:** CA  \n- **Zip:** 94109  \n- **Insurance Information:**  \n  - **Company Name:** XYZ Insurance  \n  - **Policy No.:** 987654321  \n  - **Agent Name:** Lisa Carter  \n  - **Phone:** (415) 555-9876'},
#      {'type': 'heading', 'lvl': 2, 'value': 'INJURED', 'md': '## INJURED'},
#      {'type': 'text',
#       'value': '- **Name:**  \n- **Phone:**  \n- **Address:**  \n- **City:**  \n- **State:**  \n- **Zip:**  \n- **Extent of Injury:**',
#       'md': '- **Name:**  \n- **Phone:**  \n- **Address:**  \n- **City:**  \n- **State:**  \n- **Zip:**  \n- **Extent of Injury:**'},
#      {'type': 'heading', 'lvl': 2, 'value': 'WITNESSES', 'md': '## WITNESSES'},
#      {'type': 'text',
#       'value': '- **Name:** Mia Chen  \n- **Phone:** (415) 555-5678  \n- **Address:** 5678 Beach St  \n- **City:** San Francisco  \n- **State:** CA  \n- **Zip:** 94123',
#       'md': '- **Name:** Mia Chen  \n- **Phone:** (415) 555-5678  \n- **Address:** 5678 Beach St  \n- **City:** San Francisco  \n- **State:** CA  \n- **Zip:** 94123'},
#      {'type': 'heading', 'lvl': 2, 'value': 'IMPACT', 'md': '## IMPACT'},
#      {'type': 'text',
#       'value': '- **Is damaged auto essential to business?** No  \n- **How?**',
#       'md': '- **Is damaged auto essential to business?** No  \n- **How?**'}]},
#    {'page': 3,
#     'md': '# INSTRUCTIONS TO INSURED:\n\n## If still on the scene:\n1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.\n\n## If not on the scene:\n1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.',
#     'images': [{'name': 'page-2.jpg',
#       'height': 0,
#       'width': 0,
#       'x': 0,
#       'y': 0,
#       'type': 'full_page_screenshot'}],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'INSTRUCTIONS TO INSURED:',
#       'md': '# INSTRUCTIONS TO INSURED:'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'If still on the scene:',
#       'md': '## If still on the scene:'},
#      {'type': 'text',
#       'value': '1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.',
#       'md': '1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.'},
#      {'type': 'heading',
#       'lvl': 2,
#       'value': 'If not on the scene:',
#       'md': '## If not on the scene:'},
#      {'type': 'text',
#       'value': '1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.',
#       'md': '1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.'}]}],
#   'job_metadata': {'credits_used': 0.0,
#    'job_credits_usage': 0,
#    'job_pages': 0,
#    'job_is_cache_hit': True,
#    'credits_max': 1000},
#   'job_id': 'd2b2f6b5-05e7-4517-9f13-ec7871aeaa0a',
#   'file_path': 'insurance-claims-rag-data\\claim_5.pdf'}]

# %%
parsed_images = parser.get_images(
    md_json_objs, download_path="data_images"
)  # extract images from PDFs and save them to ./data_images/
# Out:
# > Image for page 1: [{'name': 'page-0.jpg', 'height': 0, 'width': 0, 'x': 0, 'y': 0, 'type': 'full_page_screenshot'}]
# > Image for page 2: [{'name': 'page-1.jpg', 'height': 0, 'width': 0, 'x': 0, 'y': 0, 'type': 'full_page_screenshot'}]
# > Image for page 3: [{'name': 'page-2.jpg', 'height': 0, 'width': 0, 'x': 0, 'y': 0, 'type': 'full_page_screenshot'}]
# > Image for page 1: [{'name': 'page-0.jpg', 'height': 0, 'width': 0, 'x': 0, 'y': 0, 'type': 'full_page_screenshot'}]
# > Image for page 2: [{'name': 'page-1.jpg', 'height': 0, 'width': 0, 'x': 0, 'y': 0, 'type': 'full_page_screenshot'}]
# > Image for page 3: [{'name': 'page-2.jpg', 'height': 0, 'width': 0, 'x': 0, 'y': 0, 'type': 'full_page_screenshot'}]
# > Image for page 1: [{'name': 'page-0.jpg', 'height': 0, 'width': 0, 'x': 0, 'y': 0, 'type': 'full_page_screenshot'}]
# > Image for page 2: [{'name': 'page-1.jpg', 'height': 0, 'width': 0, 'x': 0, 'y': 0, 'type': 'full_page_screenshot'}]
# > Image for page 3: [{'name': 'page-2.jpg', 'height': 0, 'width': 0, 'x': 0, 'y': 0, 'type': 'full_page_screenshot'}]
# > Image for page 1: [{'name': 'page-0.jpg', 'height': 0, 'width': 0, 'x': 0, 'y': 0, 'type': 'full_page_screenshot'}]
# > Image for page 2: [{'name': 'page-1.jpg', 'height': 0, 'width': 0, 'x': 0, 'y': 0, 'type': 'full_page_screenshot'}]
# > Image for page 3: [{'name': 'page-2.jpg', 'height': 0, 'width': 0, 'x': 0, 'y': 0, 'type': 'full_page_screenshot'}]
# > Image for page 1: [{'name': 'page-0.jpg', 'height': 0, 'width': 0, 'x': 0, 'y': 0, 'type': 'full_page_screenshot'}]
# > Image for page 2: [{'name': 'page-1.jpg', 'height': 0, 'width': 0, 'x': 0, 'y': 0, 'type': 'full_page_screenshot'}]
# > Image for page 3: [{'name': 'page-2.jpg', 'height': 0, 'width': 0, 'x': 0, 'y': 0, 'type': 'full_page_screenshot'}]

# %%
mylist = []
help(mylist.extend)
# Out:
# Help on built-in function extend:
#
# extend(iterable, /) method of builtins.list instance
#     Extend list by appending elements from the iterable.

# %%
# extract list of pages for insurance claim doc
md_json_list = []
for obj in md_json_objs:
    md_json_list.extend(obj["pages"])

# %%
md_json_list
# Out:
# [{'page': 1,
#   'md': '# Auto Claims\n\nIn the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.  \n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.  \n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#   'images': [{'name': 'page-0.jpg',
#     'height': 0,
#     'width': 0,
#     'x': 0,
#     'y': 0,
#     'type': 'full_page_screenshot',
#     'path': 'data_images\\6c23082f-8b5c-4e1c-924a-24e682d7f824-page-0.jpg',
#     'job_id': '6c23082f-8b5c-4e1c-924a-24e682d7f824',
#     'original_pdf_path': 'insurance-claims-rag-data\\claim_1.pdf',
#     'page_number': 1}],
#   'items': [{'type': 'heading',
#     'lvl': 1,
#     'value': 'Auto Claims',
#     'md': '# Auto Claims'},
#    {'type': 'text',
#     'value': 'In the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.  \n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.  \n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#     'md': 'In the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.  \n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.  \n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.'}]},
#  {'page': 2,
#   'md': '\n# AUTOMOBILE CLAIM\n\n## LOSS\n- **Date:** 06/23/2023\n- **Location:** Intersection of Vine Street and Sunset Bl\n- **City:** Los Angeles\n- **State:** CA\n- **Police Dept. Involved:** LAPD\n- **Ticket Issued:** Traffic Violation\n\n## DESCRIPTION OF ACCIDENT\nOn October 15, 2023, at approximately 3:30 PM, I was driving my 2020 Honda Accord (License Plate: 7XYZ123) southbound on Vine St.\n\n## INSURED VEHICLE\n- **Year:** 2020\n- **Make:** Honda\n- **Model:** Accord\n- **V.I.N.:** 1HGCV1F30LA123456\n- **Plate:** 7XYZ123\n- **Extent of Damages:** The front passenger side of my Honda Accord sustained significant damage, including a demolished door and broken headlights. Estimated repair cost: $3,500.\n- **Driver:** Michael Johnson\n- **Date of Birth:** 01/15/1985\n- **License No.:** 1111111111\n- **State:** CA\n\n## OTHER VEHICLE\n- **Year:** 2018\n- **Make:** Ford\n- **Model:** Escape\n- **Owner:** Sarah Brown\n- **Phone:** 2139876543\n- **Extent of Damages:** The Ford Escape had damage to the front bumper and hood. Estimated repair cost: $2,000.\n- **Address:** 405 Hilgard Av\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90095\n\n## INSURANCE INFORMATION\n- **Company Name:** Morts Mutual Insurance\n- **Policy No.:** 987654321\n- **Agent Name:** Emily Carter\n- **Phone:** 2131234567\n\n## INJURED\n- **Name:** Michael Johnson\n- **Phone:** 3101234567\n- **Address:** 3470 Trousdale Pkwy\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90089\n- **Extent of Injury:** I sustained minor injuries, including neck pain and a bruise on my left arm. I sought medical attention at the local urgent care facility.\n\n## WITNESSES\n- **Name:** David Thompson\n- **Phone:** 3105678901\n- **Address:** 633 W 5th St\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90071\n\n## IMPACT\n- **Is damaged auto essential to business?** No\n- **How?** \n',
#   'images': [{'name': 'page-1.jpg',
#     'height': 0,
#     'width': 0,
#     'x': 0,
#     'y': 0,
#     'type': 'full_page_screenshot',
#     'path': 'data_images\\6c23082f-8b5c-4e1c-924a-24e682d7f824-page-1.jpg',
#     'job_id': '6c23082f-8b5c-4e1c-924a-24e682d7f824',
#     'original_pdf_path': 'insurance-claims-rag-data\\claim_1.pdf',
#     'page_number': 2}],
#   'items': [{'type': 'heading',
#     'lvl': 1,
#     'value': 'AUTOMOBILE CLAIM',
#     'md': '# AUTOMOBILE CLAIM'},
#    {'type': 'heading', 'lvl': 2, 'value': 'LOSS', 'md': '## LOSS'},
#    {'type': 'text',
#     'value': '- **Date:** 06/23/2023\n- **Location:** Intersection of Vine Street and Sunset Bl\n- **City:** Los Angeles\n- **State:** CA\n- **Police Dept. Involved:** LAPD\n- **Ticket Issued:** Traffic Violation',
#     'md': '- **Date:** 06/23/2023\n- **Location:** Intersection of Vine Street and Sunset Bl\n- **City:** Los Angeles\n- **State:** CA\n- **Police Dept. Involved:** LAPD\n- **Ticket Issued:** Traffic Violation'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'DESCRIPTION OF ACCIDENT',
#     'md': '## DESCRIPTION OF ACCIDENT'},
#    {'type': 'text',
#     'value': 'On October 15, 2023, at approximately 3:30 PM, I was driving my 2020 Honda Accord (License Plate: 7XYZ123) southbound on Vine St.',
#     'md': 'On October 15, 2023, at approximately 3:30 PM, I was driving my 2020 Honda Accord (License Plate: 7XYZ123) southbound on Vine St.'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'INSURED VEHICLE',
#     'md': '## INSURED VEHICLE'},
#    {'type': 'text',
#     'value': '- **Year:** 2020\n- **Make:** Honda\n- **Model:** Accord\n- **V.I.N.:** 1HGCV1F30LA123456\n- **Plate:** 7XYZ123\n- **Extent of Damages:** The front passenger side of my Honda Accord sustained significant damage, including a demolished door and broken headlights. Estimated repair cost: $3,500.\n- **Driver:** Michael Johnson\n- **Date of Birth:** 01/15/1985\n- **License No.:** 1111111111\n- **State:** CA',
#     'md': '- **Year:** 2020\n- **Make:** Honda\n- **Model:** Accord\n- **V.I.N.:** 1HGCV1F30LA123456\n- **Plate:** 7XYZ123\n- **Extent of Damages:** The front passenger side of my Honda Accord sustained significant damage, including a demolished door and broken headlights. Estimated repair cost: $3,500.\n- **Driver:** Michael Johnson\n- **Date of Birth:** 01/15/1985\n- **License No.:** 1111111111\n- **State:** CA'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'OTHER VEHICLE',
#     'md': '## OTHER VEHICLE'},
#    {'type': 'text',
#     'value': '- **Year:** 2018\n- **Make:** Ford\n- **Model:** Escape\n- **Owner:** Sarah Brown\n- **Phone:** 2139876543\n- **Extent of Damages:** The Ford Escape had damage to the front bumper and hood. Estimated repair cost: $2,000.\n- **Address:** 405 Hilgard Av\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90095',
#     'md': '- **Year:** 2018\n- **Make:** Ford\n- **Model:** Escape\n- **Owner:** Sarah Brown\n- **Phone:** 2139876543\n- **Extent of Damages:** The Ford Escape had damage to the front bumper and hood. Estimated repair cost: $2,000.\n- **Address:** 405 Hilgard Av\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90095'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'INSURANCE INFORMATION',
#     'md': '## INSURANCE INFORMATION'},
#    {'type': 'text',
#     'value': '- **Company Name:** Morts Mutual Insurance\n- **Policy No.:** 987654321\n- **Agent Name:** Emily Carter\n- **Phone:** 2131234567',
#     'md': '- **Company Name:** Morts Mutual Insurance\n- **Policy No.:** 987654321\n- **Agent Name:** Emily Carter\n- **Phone:** 2131234567'},
#    {'type': 'heading', 'lvl': 2, 'value': 'INJURED', 'md': '## INJURED'},
#    {'type': 'text',
#     'value': '- **Name:** Michael Johnson\n- **Phone:** 3101234567\n- **Address:** 3470 Trousdale Pkwy\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90089\n- **Extent of Injury:** I sustained minor injuries, including neck pain and a bruise on my left arm. I sought medical attention at the local urgent care facility.',
#     'md': '- **Name:** Michael Johnson\n- **Phone:** 3101234567\n- **Address:** 3470 Trousdale Pkwy\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90089\n- **Extent of Injury:** I sustained minor injuries, including neck pain and a bruise on my left arm. I sought medical attention at the local urgent care facility.'},
#    {'type': 'heading', 'lvl': 2, 'value': 'WITNESSES', 'md': '## WITNESSES'},
#    {'type': 'text',
#     'value': '- **Name:** David Thompson\n- **Phone:** 3105678901\n- **Address:** 633 W 5th St\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90071',
#     'md': '- **Name:** David Thompson\n- **Phone:** 3105678901\n- **Address:** 633 W 5th St\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90071'},
#    {'type': 'heading', 'lvl': 2, 'value': 'IMPACT', 'md': '## IMPACT'},
#    {'type': 'text',
#     'value': '- **Is damaged auto essential to business?** No\n- **How?**',
#     'md': '- **Is damaged auto essential to business?** No\n- **How?**'}]},
#  {'page': 3,
#   'md': '# INSTRUCTIONS TO INSURED:\n\n## If still on the scene:\n1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.\n\n## If not on the scene:\n1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.',
#   'images': [{'name': 'page-2.jpg',
#     'height': 0,
#     'width': 0,
#     'x': 0,
#     'y': 0,
#     'type': 'full_page_screenshot',
#     'path': 'data_images\\6c23082f-8b5c-4e1c-924a-24e682d7f824-page-2.jpg',
#     'job_id': '6c23082f-8b5c-4e1c-924a-24e682d7f824',
#     'original_pdf_path': 'insurance-claims-rag-data\\claim_1.pdf',
#     'page_number': 3}],
#   'items': [{'type': 'heading',
#     'lvl': 1,
#     'value': 'INSTRUCTIONS TO INSURED:',
#     'md': '# INSTRUCTIONS TO INSURED:'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'If still on the scene:',
#     'md': '## If still on the scene:'},
#    {'type': 'text',
#     'value': '1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.',
#     'md': '1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'If not on the scene:',
#     'md': '## If not on the scene:'},
#    {'type': 'text',
#     'value': '1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.',
#     'md': '1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.'}]},
#  {'page': 1,
#   'md': '# Auto Claims\n\n## In the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.  \n\n## In the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.  \n\n## After we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#   'images': [{'name': 'page-0.jpg',
#     'height': 0,
#     'width': 0,
#     'x': 0,
#     'y': 0,
#     'type': 'full_page_screenshot',
#     'path': 'data_images\\6f60648e-c044-4feb-a402-bc11116f5d07-page-0.jpg',
#     'job_id': '6f60648e-c044-4feb-a402-bc11116f5d07',
#     'original_pdf_path': 'insurance-claims-rag-data\\claim_2.pdf',
#     'page_number': 1}],
#   'items': [{'type': 'heading',
#     'lvl': 1,
#     'value': 'Auto Claims',
#     'md': '# Auto Claims'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'In the event of an automobile accident:',
#     'md': '## In the event of an automobile accident:'},
#    {'type': 'text',
#     'value': '1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.',
#     'md': '1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'In the event of a windshield, vandalism or theft loss:',
#     'md': '## In the event of a windshield, vandalism or theft loss:'},
#    {'type': 'text',
#     'value': '1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.',
#     'md': '1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'After we report the claim to the insurance company, the claims adjuster will:',
#     'md': '## After we report the claim to the insurance company, the claims adjuster will:'},
#    {'type': 'text',
#     'value': '1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#     'md': '1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.'}]},
#  {'page': 2,
#   'md': '\n# AUTOMOBILE CLAIM\n\n## LOSS\n- **Date:** 10/15/2023\n- **Location:** Intersection of 5th Ave and Elm St\n- **City:** Chicago\n- **State:** IL\n- **Police Dept. Involved:** CPD\n- **Ticket Issued:** Traffic Violation Ticket\n\n## DESCRIPTION OF ACCIDENT\nI was traveling north on 5th Ave when the other vehicle, which was traveling east on Elm St, failed to stop at a red light and collided with the front passenger side of my vehicle. The impact caused significant damage to my car and minor injuries to me.\n\n## INSURED VEHICLE\n- **Year:** 2020\n- **Make:** Honda\n- **Model:** Accord\n- **V.I.N.:** 1HGCV1F30LA123456\n- **Plate:** XYZ 1234\n- **Extent of Damages:** Front bumper, hood, fenders, head/tailights, windshield, doors\n- **Driver:** John Doe\n- **Date of Birth:** January 15, 1985\n- **License No.:** ABC123456\n- **State:** IL\n\n## OTHER VEHICLE\n- **Year:** 2018\n- **Make:** Ford\n- **Model:** F-150\n- **Owner:** Michael Green\n- **Phone:** 3129999999\n- **Address:** 321 Main St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601\n\n## INSURANCE INFORMATION\n- **Company Name:** XYZ Insurance\n- **Policy No.:** 987654321\n- **Agent Name:** \n- **Phone:** \n\n## INJURED\n- **Name:** John Doe\n- **Phone:** (555) 123-4567\n- **Address:** 123 Main St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601\n- **Extent of Injury:** Whiplash and bruising on the right arm\n\n## WITNESSES\n- **Name:** Jane Smith\n- **Phone:** (555) 987-6543\n- **Address:** 123 Market St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601\n\n## IMPACT\n- **Is damaged auto essential to business?** No\n- **How?**\n',
#   'images': [{'name': 'page-1.jpg',
#     'height': 0,
#     'width': 0,
#     'x': 0,
#     'y': 0,
#     'type': 'full_page_screenshot',
#     'path': 'data_images\\6f60648e-c044-4feb-a402-bc11116f5d07-page-1.jpg',
#     'job_id': '6f60648e-c044-4feb-a402-bc11116f5d07',
#     'original_pdf_path': 'insurance-claims-rag-data\\claim_2.pdf',
#     'page_number': 2}],
#   'items': [{'type': 'heading',
#     'lvl': 1,
#     'value': 'AUTOMOBILE CLAIM',
#     'md': '# AUTOMOBILE CLAIM'},
#    {'type': 'heading', 'lvl': 2, 'value': 'LOSS', 'md': '## LOSS'},
#    {'type': 'text',
#     'value': '- **Date:** 10/15/2023\n- **Location:** Intersection of 5th Ave and Elm St\n- **City:** Chicago\n- **State:** IL\n- **Police Dept. Involved:** CPD\n- **Ticket Issued:** Traffic Violation Ticket',
#     'md': '- **Date:** 10/15/2023\n- **Location:** Intersection of 5th Ave and Elm St\n- **City:** Chicago\n- **State:** IL\n- **Police Dept. Involved:** CPD\n- **Ticket Issued:** Traffic Violation Ticket'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'DESCRIPTION OF ACCIDENT',
#     'md': '## DESCRIPTION OF ACCIDENT'},
#    {'type': 'text',
#     'value': 'I was traveling north on 5th Ave when the other vehicle, which was traveling east on Elm St, failed to stop at a red light and collided with the front passenger side of my vehicle. The impact caused significant damage to my car and minor injuries to me.',
#     'md': 'I was traveling north on 5th Ave when the other vehicle, which was traveling east on Elm St, failed to stop at a red light and collided with the front passenger side of my vehicle. The impact caused significant damage to my car and minor injuries to me.'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'INSURED VEHICLE',
#     'md': '## INSURED VEHICLE'},
#    {'type': 'text',
#     'value': '- **Year:** 2020\n- **Make:** Honda\n- **Model:** Accord\n- **V.I.N.:** 1HGCV1F30LA123456\n- **Plate:** XYZ 1234\n- **Extent of Damages:** Front bumper, hood, fenders, head/tailights, windshield, doors\n- **Driver:** John Doe\n- **Date of Birth:** January 15, 1985\n- **License No.:** ABC123456\n- **State:** IL',
#     'md': '- **Year:** 2020\n- **Make:** Honda\n- **Model:** Accord\n- **V.I.N.:** 1HGCV1F30LA123456\n- **Plate:** XYZ 1234\n- **Extent of Damages:** Front bumper, hood, fenders, head/tailights, windshield, doors\n- **Driver:** John Doe\n- **Date of Birth:** January 15, 1985\n- **License No.:** ABC123456\n- **State:** IL'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'OTHER VEHICLE',
#     'md': '## OTHER VEHICLE'},
#    {'type': 'text',
#     'value': '- **Year:** 2018\n- **Make:** Ford\n- **Model:** F-150\n- **Owner:** Michael Green\n- **Phone:** 3129999999\n- **Address:** 321 Main St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601',
#     'md': '- **Year:** 2018\n- **Make:** Ford\n- **Model:** F-150\n- **Owner:** Michael Green\n- **Phone:** 3129999999\n- **Address:** 321 Main St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'INSURANCE INFORMATION',
#     'md': '## INSURANCE INFORMATION'},
#    {'type': 'text',
#     'value': '- **Company Name:** XYZ Insurance\n- **Policy No.:** 987654321\n- **Agent Name:** \n- **Phone:**',
#     'md': '- **Company Name:** XYZ Insurance\n- **Policy No.:** 987654321\n- **Agent Name:** \n- **Phone:**'},
#    {'type': 'heading', 'lvl': 2, 'value': 'INJURED', 'md': '## INJURED'},
#    {'type': 'text',
#     'value': '- **Name:** John Doe\n- **Phone:** (555) 123-4567\n- **Address:** 123 Main St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601\n- **Extent of Injury:** Whiplash and bruising on the right arm',
#     'md': '- **Name:** John Doe\n- **Phone:** (555) 123-4567\n- **Address:** 123 Main St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601\n- **Extent of Injury:** Whiplash and bruising on the right arm'},
#    {'type': 'heading', 'lvl': 2, 'value': 'WITNESSES', 'md': '## WITNESSES'},
#    {'type': 'text',
#     'value': '- **Name:** Jane Smith\n- **Phone:** (555) 987-6543\n- **Address:** 123 Market St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601',
#     'md': '- **Name:** Jane Smith\n- **Phone:** (555) 987-6543\n- **Address:** 123 Market St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601'},
#    {'type': 'heading', 'lvl': 2, 'value': 'IMPACT', 'md': '## IMPACT'},
#    {'type': 'text',
#     'value': '- **Is damaged auto essential to business?** No\n- **How?**',
#     'md': '- **Is damaged auto essential to business?** No\n- **How?**'}]},
#  {'page': 3,
#   'md': '# INSTRUCTIONS TO INSURED:\n\n## If still on the scene:\n1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.\n\n## If not on the scene:\n1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.',
#   'images': [{'name': 'page-2.jpg',
#     'height': 0,
#     'width': 0,
#     'x': 0,
#     'y': 0,
#     'type': 'full_page_screenshot',
#     'path': 'data_images\\6f60648e-c044-4feb-a402-bc11116f5d07-page-2.jpg',
#     'job_id': '6f60648e-c044-4feb-a402-bc11116f5d07',
#     'original_pdf_path': 'insurance-claims-rag-data\\claim_2.pdf',
#     'page_number': 3}],
#   'items': [{'type': 'heading',
#     'lvl': 1,
#     'value': 'INSTRUCTIONS TO INSURED:',
#     'md': '# INSTRUCTIONS TO INSURED:'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'If still on the scene:',
#     'md': '## If still on the scene:'},
#    {'type': 'text',
#     'value': '1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.',
#     'md': '1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'If not on the scene:',
#     'md': '## If not on the scene:'},
#    {'type': 'text',
#     'value': '1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.',
#     'md': '1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.'}]},
#  {'page': 1,
#   'md': '# Auto Claims\n\nIn the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.  \n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.  \n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#   'images': [{'name': 'page-0.jpg',
#     'height': 0,
#     'width': 0,
#     'x': 0,
#     'y': 0,
#     'type': 'full_page_screenshot',
#     'path': 'data_images\\30277837-ac7f-4437-a716-8733f1cc5c8b-page-0.jpg',
#     'job_id': '30277837-ac7f-4437-a716-8733f1cc5c8b',
#     'original_pdf_path': 'insurance-claims-rag-data\\claim_3.pdf',
#     'page_number': 1}],
#   'items': [{'type': 'heading',
#     'lvl': 1,
#     'value': 'Auto Claims',
#     'md': '# Auto Claims'},
#    {'type': 'text',
#     'value': 'In the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.  \n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.  \n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#     'md': 'In the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.  \n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.  \n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.'}]},
#  {'page': 2,
#   'md': "\n# AUTOMOBILE CLAIM\n\n## LOSS\n- **Date:** 03/10/2023\n- **Location:** Intersection of Main St and Oak St\n- **City:** Boise\n- **State:** ID\n- **Police Dept. Involved:** Boise Police Department\n- **Ticket Issued:** \n\n## DESCRIPTION OF ACCIDENT\nOn March 10, 2023, at approximately 9:15 AM, I was heading north at a parking space in the Boise Towne Square Mall parking lot. As I checked my mirrors and blind spots, I did not see any vehicles approaching. However, the driver of Vehicle 2, Michael Chen, was driving too fast through the parking lot and failed to stop in time. This resulted in my vehicle sustaining damages to the rear bumper and trunk.\n\n## INSURED VEHICLE\n- **Year:** 2018\n- **Make:** Toyota\n- **Model:** Camry\n- **V.I.N.:** 4T1BF1FK8JU01234\n- **Plate:** GH789\n- **Extent of Damages:** Rear bumper and trunk damage, including scratches, dents, and broken taillight\n- **Driver:** Rachel Patel (ASK IF OFFICER OF CO)\n- **Date of Birth:** February 12, 1992\n- **License No.:** ID1234567\n\n## OTHER VEHICLE\n- **Year:** 2020\n- **Make:** Ford\n- **Model:** F-150\n- **Owner:** Michael Chen\n- **Phone:** 5559999999\n- **Address:** 303 Maple Avenue\n- **City:** Boise\n- **State:** ID\n- **Zip:** 83701\n\n## Insurance Information\n- **Company Name:** XYZ Insurance Company\n- **Policy No.:** 987654321\n- **Agent Name:** Michael Hawk\n- **Phone:** 2135672349\n\n## INJURED\n- **Name:** \n- **Phone:** \n- **Address:** \n- **City:** \n- **State:** \n- **Zip:** \n- **Extent of Injury:** \n\n## WITNESSES\n- **Name:** Sophia Rodriguez\n- **Phone:** 5554567890\n- **Address:** 2557 La Cienega Boulevard\n- **City:** Boise\n- **State:** ID\n- **Zip:** 83701\n\n## IMPACT\n- **Is damaged auto essential to business?** Yes\n- **How?** Rachel can't drive to work anymore.\n",
#   'images': [{'name': 'page-1.jpg',
#     'height': 0,
#     'width': 0,
#     'x': 0,
#     'y': 0,
#     'type': 'full_page_screenshot',
#     'path': 'data_images\\30277837-ac7f-4437-a716-8733f1cc5c8b-page-1.jpg',
#     'job_id': '30277837-ac7f-4437-a716-8733f1cc5c8b',
#     'original_pdf_path': 'insurance-claims-rag-data\\claim_3.pdf',
#     'page_number': 2}],
#   'items': [{'type': 'heading',
#     'lvl': 1,
#     'value': 'AUTOMOBILE CLAIM',
#     'md': '# AUTOMOBILE CLAIM'},
#    {'type': 'heading', 'lvl': 2, 'value': 'LOSS', 'md': '## LOSS'},
#    {'type': 'text',
#     'value': '- **Date:** 03/10/2023\n- **Location:** Intersection of Main St and Oak St\n- **City:** Boise\n- **State:** ID\n- **Police Dept. Involved:** Boise Police Department\n- **Ticket Issued:**',
#     'md': '- **Date:** 03/10/2023\n- **Location:** Intersection of Main St and Oak St\n- **City:** Boise\n- **State:** ID\n- **Police Dept. Involved:** Boise Police Department\n- **Ticket Issued:**'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'DESCRIPTION OF ACCIDENT',
#     'md': '## DESCRIPTION OF ACCIDENT'},
#    {'type': 'text',
#     'value': 'On March 10, 2023, at approximately 9:15 AM, I was heading north at a parking space in the Boise Towne Square Mall parking lot. As I checked my mirrors and blind spots, I did not see any vehicles approaching. However, the driver of Vehicle 2, Michael Chen, was driving too fast through the parking lot and failed to stop in time. This resulted in my vehicle sustaining damages to the rear bumper and trunk.',
#     'md': 'On March 10, 2023, at approximately 9:15 AM, I was heading north at a parking space in the Boise Towne Square Mall parking lot. As I checked my mirrors and blind spots, I did not see any vehicles approaching. However, the driver of Vehicle 2, Michael Chen, was driving too fast through the parking lot and failed to stop in time. This resulted in my vehicle sustaining damages to the rear bumper and trunk.'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'INSURED VEHICLE',
#     'md': '## INSURED VEHICLE'},
#    {'type': 'text',
#     'value': '- **Year:** 2018\n- **Make:** Toyota\n- **Model:** Camry\n- **V.I.N.:** 4T1BF1FK8JU01234\n- **Plate:** GH789\n- **Extent of Damages:** Rear bumper and trunk damage, including scratches, dents, and broken taillight\n- **Driver:** Rachel Patel (ASK IF OFFICER OF CO)\n- **Date of Birth:** February 12, 1992\n- **License No.:** ID1234567',
#     'md': '- **Year:** 2018\n- **Make:** Toyota\n- **Model:** Camry\n- **V.I.N.:** 4T1BF1FK8JU01234\n- **Plate:** GH789\n- **Extent of Damages:** Rear bumper and trunk damage, including scratches, dents, and broken taillight\n- **Driver:** Rachel Patel (ASK IF OFFICER OF CO)\n- **Date of Birth:** February 12, 1992\n- **License No.:** ID1234567'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'OTHER VEHICLE',
#     'md': '## OTHER VEHICLE'},
#    {'type': 'text',
#     'value': '- **Year:** 2020\n- **Make:** Ford\n- **Model:** F-150\n- **Owner:** Michael Chen\n- **Phone:** 5559999999\n- **Address:** 303 Maple Avenue\n- **City:** Boise\n- **State:** ID\n- **Zip:** 83701',
#     'md': '- **Year:** 2020\n- **Make:** Ford\n- **Model:** F-150\n- **Owner:** Michael Chen\n- **Phone:** 5559999999\n- **Address:** 303 Maple Avenue\n- **City:** Boise\n- **State:** ID\n- **Zip:** 83701'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'Insurance Information',
#     'md': '## Insurance Information'},
#    {'type': 'text',
#     'value': '- **Company Name:** XYZ Insurance Company\n- **Policy No.:** 987654321\n- **Agent Name:** Michael Hawk\n- **Phone:** 2135672349',
#     'md': '- **Company Name:** XYZ Insurance Company\n- **Policy No.:** 987654321\n- **Agent Name:** Michael Hawk\n- **Phone:** 2135672349'},
#    {'type': 'heading', 'lvl': 2, 'value': 'INJURED', 'md': '## INJURED'},
#    {'type': 'text',
#     'value': '- **Name:** \n- **Phone:** \n- **Address:** \n- **City:** \n- **State:** \n- **Zip:** \n- **Extent of Injury:**',
#     'md': '- **Name:** \n- **Phone:** \n- **Address:** \n- **City:** \n- **State:** \n- **Zip:** \n- **Extent of Injury:**'},
#    {'type': 'heading', 'lvl': 2, 'value': 'WITNESSES', 'md': '## WITNESSES'},
#    {'type': 'text',
#     'value': '- **Name:** Sophia Rodriguez\n- **Phone:** 5554567890\n- **Address:** 2557 La Cienega Boulevard\n- **City:** Boise\n- **State:** ID\n- **Zip:** 83701',
#     'md': '- **Name:** Sophia Rodriguez\n- **Phone:** 5554567890\n- **Address:** 2557 La Cienega Boulevard\n- **City:** Boise\n- **State:** ID\n- **Zip:** 83701'},
#    {'type': 'heading', 'lvl': 2, 'value': 'IMPACT', 'md': '## IMPACT'},
#    {'type': 'text',
#     'value': "- **Is damaged auto essential to business?** Yes\n- **How?** Rachel can't drive to work anymore.",
#     'md': "- **Is damaged auto essential to business?** Yes\n- **How?** Rachel can't drive to work anymore."}]},
#  {'page': 3,
#   'md': '# INSTRUCTIONS TO INSURED:\n\n## If still on the scene:\n1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.\n\n## If not on the scene:\n1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.',
#   'images': [{'name': 'page-2.jpg',
#     'height': 0,
#     'width': 0,
#     'x': 0,
#     'y': 0,
#     'type': 'full_page_screenshot',
#     'path': 'data_images\\30277837-ac7f-4437-a716-8733f1cc5c8b-page-2.jpg',
#     'job_id': '30277837-ac7f-4437-a716-8733f1cc5c8b',
#     'original_pdf_path': 'insurance-claims-rag-data\\claim_3.pdf',
#     'page_number': 3}],
#   'items': [{'type': 'heading',
#     'lvl': 1,
#     'value': 'INSTRUCTIONS TO INSURED:',
#     'md': '# INSTRUCTIONS TO INSURED:'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'If still on the scene:',
#     'md': '## If still on the scene:'},
#    {'type': 'text',
#     'value': '1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.',
#     'md': '1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'If not on the scene:',
#     'md': '## If not on the scene:'},
#    {'type': 'text',
#     'value': '1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.',
#     'md': '1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.'}]},
#  {'page': 1,
#   'md': '# Auto Claims\n\n## In the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.\n4. Call us to report the accident.\n\n## In the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.\n2. Call us to report a loss.\n\n## After we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates.\n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged.\n3. Contact you for a settlement.\n4. Deal directly with the others involved in the accident.\n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.\n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#   'images': [{'name': 'page-0.jpg',
#     'height': 0,
#     'width': 0,
#     'x': 0,
#     'y': 0,
#     'type': 'full_page_screenshot',
#     'path': 'data_images\\4ab8a70d-6a74-4540-9158-329cc1f2ddcf-page-0.jpg',
#     'job_id': '4ab8a70d-6a74-4540-9158-329cc1f2ddcf',
#     'original_pdf_path': 'insurance-claims-rag-data\\claim_4.pdf',
#     'page_number': 1}],
#   'items': [{'type': 'heading',
#     'lvl': 1,
#     'value': 'Auto Claims',
#     'md': '# Auto Claims'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'In the event of an automobile accident:',
#     'md': '## In the event of an automobile accident:'},
#    {'type': 'text',
#     'value': '1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.\n4. Call us to report the accident.',
#     'md': '1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.\n4. Call us to report the accident.'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'In the event of a windshield, vandalism or theft loss:',
#     'md': '## In the event of a windshield, vandalism or theft loss:'},
#    {'type': 'text',
#     'value': '1. Report the vandalism loss or theft to the police.\n2. Call us to report a loss.',
#     'md': '1. Report the vandalism loss or theft to the police.\n2. Call us to report a loss.'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'After we report the claim to the insurance company, the claims adjuster will:',
#     'md': '## After we report the claim to the insurance company, the claims adjuster will:'},
#    {'type': 'text',
#     'value': '1. Contact you to request details of the accident and repair estimates.\n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged.\n3. Contact you for a settlement.\n4. Deal directly with the others involved in the accident.\n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.\n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#     'md': '1. Contact you to request details of the accident and repair estimates.\n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged.\n3. Contact you for a settlement.\n4. Deal directly with the others involved in the accident.\n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.\n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.'}]},
#  {'page': 2,
# ...
#     'md': '1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.'}]},
#  {'page': 1,
#   'md': '# Auto Claims\n\nIn the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.\n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.\n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.\n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#   'images': [{'name': 'page-0.jpg',
#     'height': 0,
#     'width': 0,
#     'x': 0,
#     'y': 0,
#     'type': 'full_page_screenshot',
#     'path': 'data_images\\d2b2f6b5-05e7-4517-9f13-ec7871aeaa0a-page-0.jpg',
#     'job_id': 'd2b2f6b5-05e7-4517-9f13-ec7871aeaa0a',
#     'original_pdf_path': 'insurance-claims-rag-data\\claim_5.pdf',
#     'page_number': 1}],
#   'items': [{'type': 'heading',
#     'lvl': 1,
#     'value': 'Auto Claims',
#     'md': '# Auto Claims'},
#    {'type': 'text',
#     'value': 'In the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.\n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.\n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.\n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.',
#     'md': 'In the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.\n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.\n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.\n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.'}]},
#  {'page': 2,
#   'md': '# AUTOMOBILE CLAIM\n\n## LOSS\n- **Date:** October 10, 2023  \n- **Location:** Lombard Street  \n- **City:** San Francisco  \n- **State:** CA  \n- **Police Dept. Involved:** SFPD  \n- **Ticket Issued:** Traffic Violation  \n\n## DESCRIPTION OF ACCIDENT\nOn the morning of October 10, 2023, I was driving my Honda Civic License Plate: 7ABC123 down Lombard Street in San Francisco. The weather was foggy and traffic was moving slowly due to congestion. As I approached an intersection, I tried gently to maintain a safe distance from the vehicle in front of me. Suddenly, I felt a bump as Jackson Johnson, who was doing a delivery on Leavenworth Street, collided with the rear of my vehicle. The impact caused damage to the rear bumper and trunk only. I was wearing my seatbelt and did not sustain any injuries. Mark asked me whether to check on me, and we exchanged insurance information. I have attached a copy of the police report, which was filed at the scene, along with photographs of the damage to both vehicles.\n\n## INSURED VEHICLE\n- **Year:** 2010  \n- **Make:** Honda  \n- **Model:** Civic  \n- **V.I.N.:** 1HGCM82633A123456  \n- **Plate:** 7ABC123  \n- **Extent of Damages:** Damage to rear bumper, Scratches on trunk  \n- **Driver:** Emily Rodriguez  \n  - **Date of Birth:** March 15, 1991  \n  - **License No.:** D123456789  \n  - **State:** CA  \n\n## OTHER VEHICLE\n- **Year:** 2020  \n- **Make:** Ford  \n- **Model:** Transit 250  \n- **Owner:** Mark Johnson  \n- **Phone:** 415202020  \n- **Address:** 305 Leavenworth Street  \n- **City:** San Francisco  \n- **State:** CA  \n- **Zip:** 94109  \n- **Insurance Information:**  \n  - **Company Name:** XYZ Insurance  \n  - **Policy No.:** 987654321  \n  - **Agent Name:** Lisa Carter  \n  - **Phone:** (415) 555-9876  \n\n## INJURED\n- **Name:**  \n- **Phone:**  \n- **Address:**  \n- **City:**  \n- **State:**  \n- **Zip:**  \n- **Extent of Injury:**  \n\n## WITNESSES\n- **Name:** Mia Chen  \n- **Phone:** (415) 555-5678  \n- **Address:** 5678 Beach St  \n- **City:** San Francisco  \n- **State:** CA  \n- **Zip:** 94123  \n\n## IMPACT\n- **Is damaged auto essential to business?** No  \n- **How?**  ',
#   'images': [{'name': 'page-1.jpg',
#     'height': 0,
#     'width': 0,
#     'x': 0,
#     'y': 0,
#     'type': 'full_page_screenshot',
#     'path': 'data_images\\d2b2f6b5-05e7-4517-9f13-ec7871aeaa0a-page-1.jpg',
#     'job_id': 'd2b2f6b5-05e7-4517-9f13-ec7871aeaa0a',
#     'original_pdf_path': 'insurance-claims-rag-data\\claim_5.pdf',
#     'page_number': 2}],
#   'items': [{'type': 'heading',
#     'lvl': 1,
#     'value': 'AUTOMOBILE CLAIM',
#     'md': '# AUTOMOBILE CLAIM'},
#    {'type': 'heading', 'lvl': 2, 'value': 'LOSS', 'md': '## LOSS'},
#    {'type': 'text',
#     'value': '- **Date:** October 10, 2023  \n- **Location:** Lombard Street  \n- **City:** San Francisco  \n- **State:** CA  \n- **Police Dept. Involved:** SFPD  \n- **Ticket Issued:** Traffic Violation',
#     'md': '- **Date:** October 10, 2023  \n- **Location:** Lombard Street  \n- **City:** San Francisco  \n- **State:** CA  \n- **Police Dept. Involved:** SFPD  \n- **Ticket Issued:** Traffic Violation'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'DESCRIPTION OF ACCIDENT',
#     'md': '## DESCRIPTION OF ACCIDENT'},
#    {'type': 'text',
#     'value': 'On the morning of October 10, 2023, I was driving my Honda Civic License Plate: 7ABC123 down Lombard Street in San Francisco. The weather was foggy and traffic was moving slowly due to congestion. As I approached an intersection, I tried gently to maintain a safe distance from the vehicle in front of me. Suddenly, I felt a bump as Jackson Johnson, who was doing a delivery on Leavenworth Street, collided with the rear of my vehicle. The impact caused damage to the rear bumper and trunk only. I was wearing my seatbelt and did not sustain any injuries. Mark asked me whether to check on me, and we exchanged insurance information. I have attached a copy of the police report, which was filed at the scene, along with photographs of the damage to both vehicles.',
#     'md': 'On the morning of October 10, 2023, I was driving my Honda Civic License Plate: 7ABC123 down Lombard Street in San Francisco. The weather was foggy and traffic was moving slowly due to congestion. As I approached an intersection, I tried gently to maintain a safe distance from the vehicle in front of me. Suddenly, I felt a bump as Jackson Johnson, who was doing a delivery on Leavenworth Street, collided with the rear of my vehicle. The impact caused damage to the rear bumper and trunk only. I was wearing my seatbelt and did not sustain any injuries. Mark asked me whether to check on me, and we exchanged insurance information. I have attached a copy of the police report, which was filed at the scene, along with photographs of the damage to both vehicles.'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'INSURED VEHICLE',
#     'md': '## INSURED VEHICLE'},
#    {'type': 'text',
#     'value': '- **Year:** 2010  \n- **Make:** Honda  \n- **Model:** Civic  \n- **V.I.N.:** 1HGCM82633A123456  \n- **Plate:** 7ABC123  \n- **Extent of Damages:** Damage to rear bumper, Scratches on trunk  \n- **Driver:** Emily Rodriguez  \n  - **Date of Birth:** March 15, 1991  \n  - **License No.:** D123456789  \n  - **State:** CA',
#     'md': '- **Year:** 2010  \n- **Make:** Honda  \n- **Model:** Civic  \n- **V.I.N.:** 1HGCM82633A123456  \n- **Plate:** 7ABC123  \n- **Extent of Damages:** Damage to rear bumper, Scratches on trunk  \n- **Driver:** Emily Rodriguez  \n  - **Date of Birth:** March 15, 1991  \n  - **License No.:** D123456789  \n  - **State:** CA'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'OTHER VEHICLE',
#     'md': '## OTHER VEHICLE'},
#    {'type': 'text',
#     'value': '- **Year:** 2020  \n- **Make:** Ford  \n- **Model:** Transit 250  \n- **Owner:** Mark Johnson  \n- **Phone:** 415202020  \n- **Address:** 305 Leavenworth Street  \n- **City:** San Francisco  \n- **State:** CA  \n- **Zip:** 94109  \n- **Insurance Information:**  \n  - **Company Name:** XYZ Insurance  \n  - **Policy No.:** 987654321  \n  - **Agent Name:** Lisa Carter  \n  - **Phone:** (415) 555-9876',
#     'md': '- **Year:** 2020  \n- **Make:** Ford  \n- **Model:** Transit 250  \n- **Owner:** Mark Johnson  \n- **Phone:** 415202020  \n- **Address:** 305 Leavenworth Street  \n- **City:** San Francisco  \n- **State:** CA  \n- **Zip:** 94109  \n- **Insurance Information:**  \n  - **Company Name:** XYZ Insurance  \n  - **Policy No.:** 987654321  \n  - **Agent Name:** Lisa Carter  \n  - **Phone:** (415) 555-9876'},
#    {'type': 'heading', 'lvl': 2, 'value': 'INJURED', 'md': '## INJURED'},
#    {'type': 'text',
#     'value': '- **Name:**  \n- **Phone:**  \n- **Address:**  \n- **City:**  \n- **State:**  \n- **Zip:**  \n- **Extent of Injury:**',
#     'md': '- **Name:**  \n- **Phone:**  \n- **Address:**  \n- **City:**  \n- **State:**  \n- **Zip:**  \n- **Extent of Injury:**'},
#    {'type': 'heading', 'lvl': 2, 'value': 'WITNESSES', 'md': '## WITNESSES'},
#    {'type': 'text',
#     'value': '- **Name:** Mia Chen  \n- **Phone:** (415) 555-5678  \n- **Address:** 5678 Beach St  \n- **City:** San Francisco  \n- **State:** CA  \n- **Zip:** 94123',
#     'md': '- **Name:** Mia Chen  \n- **Phone:** (415) 555-5678  \n- **Address:** 5678 Beach St  \n- **City:** San Francisco  \n- **State:** CA  \n- **Zip:** 94123'},
#    {'type': 'heading', 'lvl': 2, 'value': 'IMPACT', 'md': '## IMPACT'},
#    {'type': 'text',
#     'value': '- **Is damaged auto essential to business?** No  \n- **How?**',
#     'md': '- **Is damaged auto essential to business?** No  \n- **How?**'}]},
#  {'page': 3,
#   'md': '# INSTRUCTIONS TO INSURED:\n\n## If still on the scene:\n1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.\n\n## If not on the scene:\n1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.',
#   'images': [{'name': 'page-2.jpg',
#     'height': 0,
#     'width': 0,
#     'x': 0,
#     'y': 0,
#     'type': 'full_page_screenshot',
#     'path': 'data_images\\d2b2f6b5-05e7-4517-9f13-ec7871aeaa0a-page-2.jpg',
#     'job_id': 'd2b2f6b5-05e7-4517-9f13-ec7871aeaa0a',
#     'original_pdf_path': 'insurance-claims-rag-data\\claim_5.pdf',
#     'page_number': 3}],
#   'items': [{'type': 'heading',
#     'lvl': 1,
#     'value': 'INSTRUCTIONS TO INSURED:',
#     'md': '# INSTRUCTIONS TO INSURED:'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'If still on the scene:',
#     'md': '## If still on the scene:'},
#    {'type': 'text',
#     'value': '1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.',
#     'md': '1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.'},
#    {'type': 'heading',
#     'lvl': 2,
#     'value': 'If not on the scene:',
#     'md': '## If not on the scene:'},
#    {'type': 'text',
#     'value': '1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.',
#     'md': '1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.'}]}]

# %% [markdown]
# #### Create helper functions to create a list of TextNodes from the markdown tables to feed into the VectorStoreIndex.

# %%
import re
from pathlib import Path
import typing as t
from llama_index.core.schema import TextNode, ImageNode


def get_page_number(file_name):
    """Gets page number of images using regex on file names"""
    match = re.search(r"-page-(\d+)\.jpg$", str(file_name))
    if match:
        return int(match.group(1))
    return 0


def _get_sorted_image_files(image_dir):
    """Get image files sorted by page."""
    raw_files = [f for f in list(Path(image_dir).iterdir()) if f.is_file()]
    sorted_files = sorted(raw_files, key=get_page_number)
    return sorted_files


def get_text_nodes(json_dicts, image_dir) -> t.List[TextNode]:
    """Creates nodes from json + images"""

    nodes = []

    docs = [doc["md"] for doc in json_dicts]  # extract text
    image_files = _get_sorted_image_files(image_dir)  # extract images

    for idx, doc in enumerate(docs):
        # adds both a text node and the corresponding image node (jpg of the page) for each page
        node = TextNode(
            text=doc,
            metadata={"image_path": str(image_files[idx]), "page_num": idx + 1},
        )
        image_node = ImageNode(
            image_path=str(image_files[idx]),
            metadata={"page_num": idx + 1, "text_node_id": node.id_},
        )
        nodes.extend([node, image_node])

    return nodes


text_nodes = get_text_nodes(md_json_list, "data_images")

# %%
text_nodes
# Out:
# [TextNode(id_='b08cdc24-66f0-4f00-832d-7d5cc46a7ac6', embedding=None, metadata={'image_path': 'data_images\\06fe8202-3175-47db-ae1e-fb1bb55cbc2e-page-0.jpg', 'page_num': 1}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='# Auto Claims\n\nIn the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.  \n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.  \n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  ImageNode(id_='09bd231c-fe97-4d53-9147-2b1ec7d4d47f', embedding=None, metadata={'page_num': 1, 'text_node_id': 'b08cdc24-66f0-4f00-832d-7d5cc46a7ac6'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n', image=None, image_path='data_images\\06fe8202-3175-47db-ae1e-fb1bb55cbc2e-page-0.jpg', image_url=None, image_mimetype=None, text_embedding=None),
#  TextNode(id_='50e0ff33-e725-4fb9-a959-07f834339476', embedding=None, metadata={'image_path': 'data_images\\07e84c2b-41f2-4875-83bb-adf82ccb0e72-page-0.jpg', 'page_num': 2}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='\n# AUTOMOBILE CLAIM\n\n## LOSS\n- **Date:** 06/23/2023\n- **Location:** Intersection of Vine Street and Sunset Bl\n- **City:** Los Angeles\n- **State:** CA\n- **Police Dept. Involved:** LAPD\n- **Ticket Issued:** Traffic Violation\n\n## DESCRIPTION OF ACCIDENT\nOn October 15, 2023, at approximately 3:30 PM, I was driving my 2020 Honda Accord (License Plate: 7XYZ123) southbound on Vine St.\n\n## INSURED VEHICLE\n- **Year:** 2020\n- **Make:** Honda\n- **Model:** Accord\n- **V.I.N.:** 1HGCV1F30LA123456\n- **Plate:** 7XYZ123\n- **Extent of Damages:** The front passenger side of my Honda Accord sustained significant damage, including a demolished door and broken headlights. Estimated repair cost: $3,500.\n- **Driver:** Michael Johnson\n- **Date of Birth:** 01/15/1985\n- **License No.:** 1111111111\n- **State:** CA\n\n## OTHER VEHICLE\n- **Year:** 2018\n- **Make:** Ford\n- **Model:** Escape\n- **Owner:** Sarah Brown\n- **Phone:** 2139876543\n- **Extent of Damages:** The Ford Escape had damage to the front bumper and hood. Estimated repair cost: $2,000.\n- **Address:** 405 Hilgard Av\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90095\n\n## INSURANCE INFORMATION\n- **Company Name:** Morts Mutual Insurance\n- **Policy No.:** 987654321\n- **Agent Name:** Emily Carter\n- **Phone:** 2131234567\n\n## INJURED\n- **Name:** Michael Johnson\n- **Phone:** 3101234567\n- **Address:** 3470 Trousdale Pkwy\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90089\n- **Extent of Injury:** I sustained minor injuries, including neck pain and a bruise on my left arm. I sought medical attention at the local urgent care facility.\n\n## WITNESSES\n- **Name:** David Thompson\n- **Phone:** 3105678901\n- **Address:** 633 W 5th St\n- **City:** Los Angeles\n- **State:** CA\n- **Zip:** 90071\n\n## IMPACT\n- **Is damaged auto essential to business?** No\n- **How?** \n', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  ImageNode(id_='b0c75cad-35ec-4863-9b86-8a3404be3c0c', embedding=None, metadata={'page_num': 2, 'text_node_id': '50e0ff33-e725-4fb9-a959-07f834339476'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n', image=None, image_path='data_images\\07e84c2b-41f2-4875-83bb-adf82ccb0e72-page-0.jpg', image_url=None, image_mimetype=None, text_embedding=None),
#  TextNode(id_='b2b0bc79-fbc5-4160-99e0-a30e0c275a2d', embedding=None, metadata={'image_path': 'data_images\\1ae3fe4f-f58e-47f9-b8c5-2d2e70e81f6a-page-0.jpg', 'page_num': 3}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='# INSTRUCTIONS TO INSURED:\n\n## If still on the scene:\n1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.\n\n## If not on the scene:\n1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  ImageNode(id_='a1db5e23-5b45-4635-88fa-31c8a7110291', embedding=None, metadata={'page_num': 3, 'text_node_id': 'b2b0bc79-fbc5-4160-99e0-a30e0c275a2d'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n', image=None, image_path='data_images\\1ae3fe4f-f58e-47f9-b8c5-2d2e70e81f6a-page-0.jpg', image_url=None, image_mimetype=None, text_embedding=None),
#  TextNode(id_='0f985f84-1a2e-42dd-aec9-272efe3fb3e3', embedding=None, metadata={'image_path': 'data_images\\30277837-ac7f-4437-a716-8733f1cc5c8b-page-0.jpg', 'page_num': 4}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='# Auto Claims\n\n## In the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.  \n\n## In the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.  \n\n## After we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  ImageNode(id_='6a49a694-4b8c-4f50-bf63-31a3e982e49b', embedding=None, metadata={'page_num': 4, 'text_node_id': '0f985f84-1a2e-42dd-aec9-272efe3fb3e3'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n', image=None, image_path='data_images\\30277837-ac7f-4437-a716-8733f1cc5c8b-page-0.jpg', image_url=None, image_mimetype=None, text_embedding=None),
#  TextNode(id_='322075c5-be7f-4fd4-8f47-f4b8ca35a784', embedding=None, metadata={'image_path': 'data_images\\4ab8a70d-6a74-4540-9158-329cc1f2ddcf-page-0.jpg', 'page_num': 5}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='\n# AUTOMOBILE CLAIM\n\n## LOSS\n- **Date:** 10/15/2023\n- **Location:** Intersection of 5th Ave and Elm St\n- **City:** Chicago\n- **State:** IL\n- **Police Dept. Involved:** CPD\n- **Ticket Issued:** Traffic Violation Ticket\n\n## DESCRIPTION OF ACCIDENT\nI was traveling north on 5th Ave when the other vehicle, which was traveling east on Elm St, failed to stop at a red light and collided with the front passenger side of my vehicle. The impact caused significant damage to my car and minor injuries to me.\n\n## INSURED VEHICLE\n- **Year:** 2020\n- **Make:** Honda\n- **Model:** Accord\n- **V.I.N.:** 1HGCV1F30LA123456\n- **Plate:** XYZ 1234\n- **Extent of Damages:** Front bumper, hood, fenders, head/tailights, windshield, doors\n- **Driver:** John Doe\n- **Date of Birth:** January 15, 1985\n- **License No.:** ABC123456\n- **State:** IL\n\n## OTHER VEHICLE\n- **Year:** 2018\n- **Make:** Ford\n- **Model:** F-150\n- **Owner:** Michael Green\n- **Phone:** 3129999999\n- **Address:** 321 Main St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601\n\n## INSURANCE INFORMATION\n- **Company Name:** XYZ Insurance\n- **Policy No.:** 987654321\n- **Agent Name:** \n- **Phone:** \n\n## INJURED\n- **Name:** John Doe\n- **Phone:** (555) 123-4567\n- **Address:** 123 Main St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601\n- **Extent of Injury:** Whiplash and bruising on the right arm\n\n## WITNESSES\n- **Name:** Jane Smith\n- **Phone:** (555) 987-6543\n- **Address:** 123 Market St\n- **City:** Chicago\n- **State:** IL\n- **Zip:** 60601\n\n## IMPACT\n- **Is damaged auto essential to business?** No\n- **How?**\n', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  ImageNode(id_='1bd2ba0a-54a9-427f-a4e6-fc5c4e528cda', embedding=None, metadata={'page_num': 5, 'text_node_id': '322075c5-be7f-4fd4-8f47-f4b8ca35a784'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n', image=None, image_path='data_images\\4ab8a70d-6a74-4540-9158-329cc1f2ddcf-page-0.jpg', image_url=None, image_mimetype=None, text_embedding=None),
#  TextNode(id_='a0dfc48b-ddb9-4f21-bf29-f2f065902301', embedding=None, metadata={'image_path': 'data_images\\532cb3d3-5d54-49ff-8cf5-a33cadfbfc8e-page-0.jpg', 'page_num': 6}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='# INSTRUCTIONS TO INSURED:\n\n## If still on the scene:\n1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.\n\n## If not on the scene:\n1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  ImageNode(id_='34fa7dfe-78d4-4a53-a475-e39ccd094d93', embedding=None, metadata={'page_num': 6, 'text_node_id': 'a0dfc48b-ddb9-4f21-bf29-f2f065902301'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n', image=None, image_path='data_images\\532cb3d3-5d54-49ff-8cf5-a33cadfbfc8e-page-0.jpg', image_url=None, image_mimetype=None, text_embedding=None),
#  TextNode(id_='63438e59-c3cc-41d0-a8a6-ada2bfcb2f8a', embedding=None, metadata={'image_path': 'data_images\\542a028e-eba7-4714-b330-643ab145cdfc-page-0.jpg', 'page_num': 7}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='# Auto Claims\n\nIn the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.  \n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.  \n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.  \n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  ImageNode(id_='3be05dcb-d535-4f6d-96f3-da11f7bb8684', embedding=None, metadata={'page_num': 7, 'text_node_id': '63438e59-c3cc-41d0-a8a6-ada2bfcb2f8a'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n', image=None, image_path='data_images\\542a028e-eba7-4714-b330-643ab145cdfc-page-0.jpg', image_url=None, image_mimetype=None, text_embedding=None),
#  TextNode(id_='c4ee501c-1cbe-48c5-8f51-0c482ab239f8', embedding=None, metadata={'image_path': 'data_images\\56e59dce-475f-4e89-b3ef-d29c2db2d815-page-0.jpg', 'page_num': 8}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="\n# AUTOMOBILE CLAIM\n\n## LOSS\n- **Date:** 03/10/2023\n- **Location:** Intersection of Main St and Oak St\n- **City:** Boise\n- **State:** ID\n- **Police Dept. Involved:** Boise Police Department\n- **Ticket Issued:** \n\n## DESCRIPTION OF ACCIDENT\nOn March 10, 2023, at approximately 9:15 AM, I was heading north at a parking space in the Boise Towne Square Mall parking lot. As I checked my mirrors and blind spots, I did not see any vehicles approaching. However, the driver of Vehicle 2, Michael Chen, was driving too fast through the parking lot and failed to stop in time. This resulted in my vehicle sustaining damages to the rear bumper and trunk.\n\n## INSURED VEHICLE\n- **Year:** 2018\n- **Make:** Toyota\n- **Model:** Camry\n- **V.I.N.:** 4T1BF1FK8JU01234\n- **Plate:** GH789\n- **Extent of Damages:** Rear bumper and trunk damage, including scratches, dents, and broken taillight\n- **Driver:** Rachel Patel (ASK IF OFFICER OF CO)\n- **Date of Birth:** February 12, 1992\n- **License No.:** ID1234567\n\n## OTHER VEHICLE\n- **Year:** 2020\n- **Make:** Ford\n- **Model:** F-150\n- **Owner:** Michael Chen\n- **Phone:** 5559999999\n- **Address:** 303 Maple Avenue\n- **City:** Boise\n- **State:** ID\n- **Zip:** 83701\n\n## Insurance Information\n- **Company Name:** XYZ Insurance Company\n- **Policy No.:** 987654321\n- **Agent Name:** Michael Hawk\n- **Phone:** 2135672349\n\n## INJURED\n- **Name:** \n- **Phone:** \n- **Address:** \n- **City:** \n- **State:** \n- **Zip:** \n- **Extent of Injury:** \n\n## WITNESSES\n- **Name:** Sophia Rodriguez\n- **Phone:** 5554567890\n- **Address:** 2557 La Cienega Boulevard\n- **City:** Boise\n- **State:** ID\n- **Zip:** 83701\n\n## IMPACT\n- **Is damaged auto essential to business?** Yes\n- **How?** Rachel can't drive to work anymore.\n", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  ImageNode(id_='615901e3-96f2-4eeb-a55e-28587d0493e3', embedding=None, metadata={'page_num': 8, 'text_node_id': 'c4ee501c-1cbe-48c5-8f51-0c482ab239f8'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n', image=None, image_path='data_images\\56e59dce-475f-4e89-b3ef-d29c2db2d815-page-0.jpg', image_url=None, image_mimetype=None, text_embedding=None),
#  TextNode(id_='09366306-33d4-4028-94c9-e030bef41ec7', embedding=None, metadata={'image_path': 'data_images\\56ecdbf8-2743-469d-b48a-e4ce4d0128f8-page-0.jpg', 'page_num': 9}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='# INSTRUCTIONS TO INSURED:\n\n## If still on the scene:\n1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.\n\n## If not on the scene:\n1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  ImageNode(id_='8099ca0e-946c-4e34-b02a-2c5bbd0e1308', embedding=None, metadata={'page_num': 9, 'text_node_id': '09366306-33d4-4028-94c9-e030bef41ec7'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n', image=None, image_path='data_images\\56ecdbf8-2743-469d-b48a-e4ce4d0128f8-page-0.jpg', image_url=None, image_mimetype=None, text_embedding=None),
#  TextNode(id_='c7416773-d04d-4b2c-84fe-e594f3e9a343', embedding=None, metadata={'image_path': 'data_images\\6c23082f-8b5c-4e1c-924a-24e682d7f824-page-0.jpg', 'page_num': 10}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='# Auto Claims\n\n## In the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.\n4. Call us to report the accident.\n\n## In the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.\n2. Call us to report a loss.\n\n## After we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates.\n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged.\n3. Contact you for a settlement.\n4. Deal directly with the others involved in the accident.\n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.\n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  ImageNode(id_='568fc392-bdfe-46bf-8d9f-cc863a027a97', embedding=None, metadata={'page_num': 10, 'text_node_id': 'c7416773-d04d-4b2c-84fe-e594f3e9a343'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n', image=None, image_path='data_images\\6c23082f-8b5c-4e1c-924a-24e682d7f824-page-0.jpg', image_url=None, image_mimetype=None, text_embedding=None),
#  TextNode(id_='88ae2e7b-90cc-4fc5-89c6-007acfe4a160', embedding=None, metadata={'image_path': 'data_images\\6f60648e-c044-4feb-a402-bc11116f5d07-page-0.jpg', 'page_num': 11}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='\n# AUTOMOBILE CLAIM\n\n## LOSS\n- **Date:** 11/20/2023  \n- **Location:** 10th Avenue and Pine St  \n- **City:** Seattle  \n- **State:** WA  \n- **Police Dept. Involved:** Seattle PD  \n- **Ticket Issued:** \n\n## DESCRIPTION OF ACCIDENT\nOn October 15, 2023, at approximately 4:15 PM, I was driving my 2019 Toyota Camry, License Plate LMN 4321, northbound on 10th Avenue, approaching the intersection with Pine Street. The weather was clear, and traffic was moderate. As I entered the intersection, a vehicle (Honda Civic) was traveling east on Pine Street and collided with the driver side of my vehicle. After the impact, both vehicles came to a stop in the intersection. I immediately checked for injuries and called 911 to report the accident.\n\n## INSURED VEHICLE\n- **Year:** 2019  \n- **Make:** Toyota  \n- **Model:** RAV4  \n- **V.I.N.:** 2T3B1RFV3JW112456  \n- **Plate:** LMN 4321  \n- **Extent of Damages:** My vehicle (2019 Toyota RAV4) sustained damage to the front bumper and hood, with visible dents and scratches.  \n- **Present Location:** Impound Lot  \n- **Driver:** Sarah Johnson  \n- **Date of Birth:** January 23, 1985  \n- **License No.:** S123-456-7890-XYZ  \n- **State:** WA  \n\n## OTHER VEHICLE\n- **Year:** 2016  \n- **Make:** Honda  \n- **Model:** Civic  \n- **Owner:** Mike Peter  \n- **Phone:** 4051025723  \n- **Address:** 302 Aurora Avenue  \n- **City:** Seattle  \n- **State:** WA  \n- **Zip:** 98102  \n\n## Insurance Information\n- **Company Name:** North Mutual Insurance  \n- **Policy No.:** DEF987654  \n- **Agent Name:** John Smith  \n- **Phone:** 3912835621  \n\n## INJURED\n- **Name:** Sarah Johnson  \n- **Phone:** (555) 234-5678  \n- **Address:** 456 Oak Avenue  \n- **City:** Seattle  \n- **State:** WA  \n- **Zip:** 98102  \n- **Extent of Injury:** I experienced minor injuries, including a bruised knee and some whiplash.  \n\n## WITNESSES\n- **Name:** Mark Thompson  \n- **Phone:** 5553456789  \n- **Address:** 222 1st St  \n- **City:** Seattle  \n- **State:** WA  \n- **Zip:** 98102  \n\n## IMPACT\n- **Is damaged auto essential to business?** No  \n- **How?** \n', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  ImageNode(id_='c0a36742-272e-42e1-85a3-261bcd3ae24e', embedding=None, metadata={'page_num': 11, 'text_node_id': '88ae2e7b-90cc-4fc5-89c6-007acfe4a160'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n', image=None, image_path='data_images\\6f60648e-c044-4feb-a402-bc11116f5d07-page-0.jpg', image_url=None, image_mimetype=None, text_embedding=None),
#  TextNode(id_='dc17b3eb-492b-45b8-bd78-4342f0324205', embedding=None, metadata={'image_path': 'data_images\\83329939-e1af-4cf9-b7db-a725e59b2b83-page-0.jpg', 'page_num': 12}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='# INSTRUCTIONS TO INSURED:\n\n## If still on the scene:\n1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.\n\n## If not on the scene:\n1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  ImageNode(id_='b356877c-9bad-494d-88fa-8c3748a1ad45', embedding=None, metadata={'page_num': 12, 'text_node_id': 'dc17b3eb-492b-45b8-bd78-4342f0324205'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n', image=None, image_path='data_images\\83329939-e1af-4cf9-b7db-a725e59b2b83-page-0.jpg', image_url=None, image_mimetype=None, text_embedding=None),
#  TextNode(id_='e34ec835-e454-4b48-8524-114b8c2ce2c0', embedding=None, metadata={'image_path': 'data_images\\93ba0795-79a9-41be-9cfe-9a0021e42481-page-0.jpg', 'page_num': 13}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='# Auto Claims\n\nIn the event of an automobile accident:\n1. Report the accident to the police.\n2. Obtain information about the other people involved in the accident such as:\n   a. Names, addresses and phone numbers  \n   b. Insurance company  \n   c. Type of vehicle  \n   d. Auto and driver’s license numbers.  \n3. Have your vehicle towed to the nearest repair shop if the vehicle is not drivable. Do not authorize repairs until the claims adjuster gives you the authority to do so.  \n4. Call us to report the accident.\n\nIn the event of a windshield, vandalism or theft loss:\n1. Report the vandalism loss or theft to the police.  \n2. Call us to report a loss.\n\nAfter we report the claim to the insurance company, the claims adjuster will:\n1. Contact you to request details of the accident and repair estimates  \n2. Arrange for an appraiser to inspect the damages of vehicles that are not drivable or extensively damaged  \n3. Contact you for a settlement  \n4. Deal directly with the others involved in the accident  \n\nYou should not talk to others involved in the accident, but refer them to your claims adjuster.\n\nIf at any time the claim is not being handled to your satisfaction or should you need assistance, please contact.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  ImageNode(id_='74ecff1c-2de9-483b-b8fd-f06ba4ab28a9', embedding=None, metadata={'page_num': 13, 'text_node_id': 'e34ec835-e454-4b48-8524-114b8c2ce2c0'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n', image=None, image_path='data_images\\93ba0795-79a9-41be-9cfe-9a0021e42481-page-0.jpg', image_url=None, image_mimetype=None, text_embedding=None),
#  TextNode(id_='d5d80379-a0e6-4cb3-941b-a9d5092cfc75', embedding=None, metadata={'image_path': 'data_images\\950ce423-24b2-4304-93fd-1f3d6a6befd7-page-0.jpg', 'page_num': 14}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='# AUTOMOBILE CLAIM\n\n## LOSS\n- **Date:** October 10, 2023  \n- **Location:** Lombard Street  \n- **City:** San Francisco  \n- **State:** CA  \n- **Police Dept. Involved:** SFPD  \n- **Ticket Issued:** Traffic Violation  \n\n## DESCRIPTION OF ACCIDENT\nOn the morning of October 10, 2023, I was driving my Honda Civic License Plate: 7ABC123 down Lombard Street in San Francisco. The weather was foggy and traffic was moving slowly due to congestion. As I approached an intersection, I tried gently to maintain a safe distance from the vehicle in front of me. Suddenly, I felt a bump as Jackson Johnson, who was doing a delivery on Leavenworth Street, collided with the rear of my vehicle. The impact caused damage to the rear bumper and trunk only. I was wearing my seatbelt and did not sustain any injuries. Mark asked me whether to check on me, and we exchanged insurance information. I have attached a copy of the police report, which was filed at the scene, along with photographs of the damage to both vehicles.\n\n## INSURED VEHICLE\n- **Year:** 2010  \n- **Make:** Honda  \n- **Model:** Civic  \n- **V.I.N.:** 1HGCM82633A123456  \n- **Plate:** 7ABC123  \n- **Extent of Damages:** Damage to rear bumper, Scratches on trunk  \n- **Driver:** Emily Rodriguez  \n  - **Date of Birth:** March 15, 1991  \n  - **License No.:** D123456789  \n  - **State:** CA  \n\n## OTHER VEHICLE\n- **Year:** 2020  \n- **Make:** Ford  \n- **Model:** Transit 250  \n- **Owner:** Mark Johnson  \n- **Phone:** 415202020  \n- **Address:** 305 Leavenworth Street  \n- **City:** San Francisco  \n- **State:** CA  \n- **Zip:** 94109  \n- **Insurance Information:**  \n  - **Company Name:** XYZ Insurance  \n  - **Policy No.:** 987654321  \n  - **Agent Name:** Lisa Carter  \n  - **Phone:** (415) 555-9876  \n\n## INJURED\n- **Name:**  \n- **Phone:**  \n- **Address:**  \n- **City:**  \n- **State:**  \n- **Zip:**  \n- **Extent of Injury:**  \n\n## WITNESSES\n- **Name:** Mia Chen  \n- **Phone:** (415) 555-5678  \n- **Address:** 5678 Beach St  \n- **City:** San Francisco  \n- **State:** CA  \n- **Zip:** 94123  \n\n## IMPACT\n- **Is damaged auto essential to business?** No  \n- **How?**  ', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  ImageNode(id_='f51d373a-a3be-4f40-b6b4-51fd4fc02804', embedding=None, metadata={'page_num': 14, 'text_node_id': 'd5d80379-a0e6-4cb3-941b-a9d5092cfc75'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n', image=None, image_path='data_images\\950ce423-24b2-4304-93fd-1f3d6a6befd7-page-0.jpg', image_url=None, image_mimetype=None, text_embedding=None),
#  TextNode(id_='03aced94-8630-47ea-a531-553c27eac24f', embedding=None, metadata={'image_path': 'data_images\\a026e286-b050-4f80-999f-d25781aa231a-page-0.jpg', 'page_num': 15}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='# INSTRUCTIONS TO INSURED:\n\n## If still on the scene:\n1. Contact police.\n2. Obtain information about other people involved in the accident or anyone who may have witnessed the accident.\n   - Name\n   - Address\n   - Phone number\n   - Insurance carrier\n   - Policy number\n   - Etc.\n3. Take photos of the accident, if camera available.\n4. Have vehicle towed if unable to drive.\n\n## If not on the scene:\n1. Obtain two estimates for repair if vehicle can be driven.\n2. The claims adjuster will either approve one of these two estimates or send an appraiser to see the vehicle.\n3. The claims adjuster will deal directly with the other people involved in the accident; you should not deal with them yourself.\n4. The insurance company will contact you within 48 hours.\n   - If there is any reason that you need to be contacted immediately, please let us know.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  ImageNode(id_='c14da45f-6810-4160-923a-707bdf32e15c', embedding=None, metadata={'page_num': 15, 'text_node_id': '03aced94-8630-47ea-a531-553c27eac24f'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n', image=None, image_path='data_images\\a026e286-b050-4f80-999f-d25781aa231a-page-0.jpg', image_url=None, image_mimetype=None, text_embedding=None)]

# %% [markdown]
# #### Import vector and ai search packages

# %%
import logging
import sys
from azure.core.credentials import AzureKeyCredential
from azure.search.documents import SearchClient
from azure.search.documents.indexes import SearchIndexClient
from IPython.display import Markdown, display
from llama_index.core import (
    SimpleDirectoryReader,
    StorageContext,
    VectorStoreIndex,
)
from llama_index.core.settings import Settings

from llama_index.llms.azure_openai import AzureOpenAI
from llama_index.embeddings.azure_openai import AzureOpenAIEmbedding
from llama_index.vector_stores.azureaisearch import AzureAISearchVectorStore
from llama_index.vector_stores.azureaisearch import (
    IndexManagement,
    MetadataIndexFieldType,
)
from llama_index.core.vector_stores.types import VectorStoreQueryMode

# %%
# Create azure open ai embedding

"""
This code loads and sets the necessary variables for Azure services.
The variables are loaded from Azure Key Vault.
"""

from llama_index.embeddings.azure_openai import AzureOpenAIEmbedding

azure_openai_endpoint=client.get_secret(name="aoai-endpoint").value
azure_openai_api_key=client.get_secret(name="aoai-api-key").value
azure_openai_api_version = "2024-02-15-preview"
azure_openai_embedding_deployment = client.get_secret(name="aoai-embedding-deployment").value
search_credential = AzureKeyCredential(client.get_secret(name="aisearch-adminkey").value)
search_endpoint = client.get_secret(name="aisearch-endpoint").value


azure_openai_client = AzureOpenAI(
        model=client.get_secret(name="aoai-deploymentname").value,
        api_key=azure_openai_api_key, 
        api_version=azure_openai_api_version,
        azure_deployment=client.get_secret(name="aoai-deploymentname").value,
        azure_endpoint=azure_openai_endpoint)
    

# You need to deploy your own embedding model as well as your own chat completion model
embed_model = AzureOpenAIEmbedding(
    model="text-embedding-ada-002",
    deployment_name=azure_openai_embedding_deployment,
    api_key=azure_openai_api_key,
    azure_endpoint=azure_openai_endpoint,
    api_version="2024-02-15-preview"
)

# %% [markdown]
# #### Setup Azure AI Search

# %%
# Index name to use
index_name = "llama-insurance-index"

# Use index client to demonstrate creating an index
index_client = SearchIndexClient(
    endpoint=search_endpoint,
    credential=search_credential,
)

# Use search client to demonstration using existing index
search_client = SearchClient(
    endpoint=search_endpoint,
    index_name=index_name,
    credential=search_credential,
)

# %% [markdown]
# #### Use Existing Index

# %%
vector_store = AzureAISearchVectorStore(
    search_or_index_client=search_client,
    index_management=IndexManagement.VALIDATE_INDEX,
    id_field_key="id",
    chunk_field_key="chunk",
    embedding_field_key="embedding",
    embedding_dimensionality=1536,
    metadata_string_field_key="metadata",
    doc_id_field_key="doc_id",
)

# %%
# storage_context = StorageContext.from_defaults(vector_store=vector_store)
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# %%
Settings.llm = azure_openai_client

# %%
Settings.embed_model = embed_model

# %% [markdown]
# #### Upload claims data chunks to existing Azure AI Search Index

# %%
index = VectorStoreIndex(text_nodes, embed_model=embed_model, storage_context=storage_context)

# %%
# Query Data
query_engine = index.as_query_engine(similarity_top_k=3)

# %% [markdown]
# #### Start example queries

# %%
from IPython.display import display, Markdown

response = query_engine.query(
    "Who filed the insurance claim for the accident that happened on Sunset Blvd?"
)
display(Markdown(str(response)))
# Out:
# Michael Johnson filed the insurance claim for the accident that happened on Sunset Blvd.

# %%
from IPython.display import display, Markdown

response = query_engine.query(
    "Did Ms. Johnson sustain any injuries?"
)
display(Markdown(str(response)))
# Out:
# Yes, Ms. Johnson sustained minor injuries, including a bruised knee and some whiplash.

# %% [markdown]
# #### Setup Autogen AI Agents

# %%
from autogen import AssistantAgent, UserProxyAgent, register_function
from typing_extensions import List, Annotated
import autogen
from azure.search.documents.models import VectorizableTextQuery
from azure.search.documents.models import (
    QueryType,
    QueryCaptionType,
    QueryAnswerType
)

# %%
llm_config = {
    "config_list": [
        {
            "model": client.get_secret(name="aoai-deploymentname").value,
            "api_key": client.get_secret(name="aoai-api-key").value,
            "base_url": client.get_secret(name="aoai-endpoint").value,
            "api_type": "azure",
            "api_version": "2024-02-15-preview",
        },
    ]
}

gpt4_config = {
    "cache_seed": 42,
    "temperature": 0,
    "config_list": llm_config["config_list"],
    "timeout": 120
}


ai_search_agent = AssistantAgent(
    name="AISearchAssistant",
    system_message="You are a helpful AI agent."
    "You can help with Azure AI Search service."
    "Return TERMINATE when the task is done",
    llm_config=gpt4_config,
)

user_proxy = UserProxyAgent(
    name="User",
    is_termination_msg=lambda x: "terminate" in x.get("content", "").lower()
    if x.get("content", "") is not None
    else False,
    human_input_mode="NEVER",
    max_consecutive_auto_reply=10,
    code_execution_config=False,
)

# %% [markdown]
# #### Define custom function for function calling.

# %%
@user_proxy.register_for_execution()
@ai_search_agent.register_for_llm(
    description="A tool or function for search retrieval from Azure AI Search"
)
def search_retrieval(user_input:str) -> str:
        """
        Search and retrieve answers from Azure AI Search.
        Returns:
            str
        """
        query = user_input
        search_client = SearchClient(endpoint=search_endpoint, index_name=index_name, credential=search_credential)
        vector_query = VectorizableTextQuery(text=query, k_nearest_neighbors=5, fields="embedding", exhaustive=True)

        r = search_client.search(  
        search_text=query,
        vector_queries=[vector_query],
        select=["id", "chunk"],
        query_type=QueryType.SEMANTIC,
        semantic_configuration_name='mySemanticConfig',
        query_caption=QueryCaptionType.EXTRACTIVE,
        query_answer=QueryAnswerType.EXTRACTIVE,
        top=1
    )
        #query_result = results.get_answers()[0].text
        results = [doc["chunk"].replace("\n", "").replace("\r", "") for doc in r]
        content = "\n".join(results)
        return content

# %% [markdown]
# #### Initiate agent chat

# %%
message = "Search for 'How did Ms. Patel's accident happen' in the above defined index?"

agent_response = await user_proxy.a_initiate_chat(recipient=ai_search_agent, message=message)
# Out:
# User (to AISearchAssistant):
#
# Search for 'How did Ms. Patel's accident happen' in the above defined index?
#
# --------------------------------------------------------------------------------
# AISearchAssistant (to User):
#
# ***** Suggested tool call (call_I8sNTSbzJJSSWvVE7qIpqDIs): search_retrieval *****
# Arguments:
# {"user_input":"How did Ms. Patel's accident happen"}
# *********************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING ASYNC FUNCTION search_retrieval...
# [runtime logging] log_function_use: autogen logger is None
# User (to AISearchAssistant):
#
# User (to AISearchAssistant):
#
# ***** Response from calling tool (call_I8sNTSbzJJSSWvVE7qIpqDIs) *****
# # AUTOMOBILE CLAIM## LOSS- **Date:** 03/10/2023- **Location:** Intersection of Main St and Oak St- **City:** Boise- **State:** ID- **Police Dept. Involved:** Boise Police Department- **Ticket Issued:** ## DESCRIPTION OF ACCIDENTOn March 10, 2023, at approximately 9:15 AM, I was heading north at a parking space in the Boise Towne Square Mall parking lot. As I checked my mirrors and blind spots, I did not see any vehicles approaching. However, the driver of Vehicle 2, Michael Chen, was driving too fast through the parking lot and failed to stop in time. This resulted in my vehicle sustaining damages to the rear bumper and trunk.## INSURED VEHICLE- **Year:** 2018- **Make:** Toyota- **Model:** Camry- **V.I.N.:** 4T1BF1FK8JU01234- **Plate:** GH789- **Extent of Damages:** Rear bumper and trunk damage, including scratches, dents, and broken taillight- **Driver:** Rachel Patel (ASK IF OFFICER OF CO)- **Date of Birth:** February 12, 1992- **License No.:** ID1234567## OTHER VEHICLE- **Year:** 2020- **Make:** Ford- **Model:** F-150- **Owner:** Michael Chen- **Phone:** 5559999999- **Address:** 303 Maple Avenue- **City:** Boise- **State:** ID- **Zip:** 83701## Insurance Information- **Company Name:** XYZ Insurance Company- **Policy No.:** 987654321- **Agent Name:** Michael Hawk- **Phone:** 2135672349## INJURED- **Name:** - **Phone:** - **Address:** - **City:** - **State:** - **Zip:** - **Extent of Injury:** ## WITNESSES- **Name:** Sophia Rodriguez- **Phone:** 5554567890- **Address:** 2557 La Cienega Boulevard- **City:** Boise- **State:** ID- **Zip:** 83701## IMPACT- **Is damaged auto essential to business?** Yes- **How?** Rachel can't drive to work anymore.
# **********************************************************************
#
# --------------------------------------------------------------------------------
# AISearchAssistant (to User):
#
# Ms. Patel's accident occurred on March 10, 2023, at approximately 9:15 AM in the Boise Towne Square Mall parking lot. She was heading north at a parking space and, after checking her mirrors and blind spots, did not see any approaching vehicles. However, Michael Chen, the driver of the other vehicle, was driving too fast through the parking lot and failed to stop in time, resulting in damages to the rear bumper and trunk of Ms. Patel's vehicle.
#
# TERMINATE
#
# --------------------------------------------------------------------------------

# %%
message = "Search for 'Who filed the insurance claim for the accident that happened on Sunset Blvd?' in the above defined index?"

agent_response = await user_proxy.a_initiate_chat(recipient=ai_search_agent, message=message)
# Out:
# User (to AISearchAssistant):
#
# Search for 'Who filed the insurance claim for the accident that happened on Sunset Blvd?' in the above defined index?
#
# --------------------------------------------------------------------------------
# AISearchAssistant (to User):
#
# ***** Suggested tool call (call_BrPFDx8dyw1mUIgMjDrw4k1w): search_retrieval *****
# Arguments:
# {"user_input":"Who filed the insurance claim for the accident that happened on Sunset Blvd?"}
# *********************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING ASYNC FUNCTION search_retrieval...
# [runtime logging] log_function_use: autogen logger is None
# User (to AISearchAssistant):
#
# User (to AISearchAssistant):
#
# ***** Response from calling tool (call_BrPFDx8dyw1mUIgMjDrw4k1w) *****
# # AUTOMOBILE CLAIM## LOSS- **Date:** 06/23/2023- **Location:** Intersection of Vine Street and Sunset Bl- **City:** Los Angeles- **State:** CA- **Police Dept. Involved:** LAPD- **Ticket Issued:** Traffic Violation## DESCRIPTION OF ACCIDENTOn October 15, 2023, at approximately 3:30 PM, I was driving my 2020 Honda Accord (License Plate: 7XYZ123) southbound on Vine St.## INSURED VEHICLE- **Year:** 2020- **Make:** Honda- **Model:** Accord- **V.I.N.:** 1HGCV1F30LA123456- **Plate:** 7XYZ123- **Extent of Damages:** The front passenger side of my Honda Accord sustained significant damage, including a demolished door and broken headlights. Estimated repair cost: $3,500.- **Driver:** Michael Johnson- **Date of Birth:** 01/15/1985- **License No.:** 1111111111- **State:** CA## OTHER VEHICLE- **Year:** 2018- **Make:** Ford- **Model:** Escape- **Owner:** Sarah Brown- **Phone:** 2139876543- **Extent of Damages:** The Ford Escape had damage to the front bumper and hood. Estimated repair cost: $2,000.- **Address:** 405 Hilgard Av- **City:** Los Angeles- **State:** CA- **Zip:** 90095## INSURANCE INFORMATION- **Company Name:** Morts Mutual Insurance- **Policy No.:** 987654321- **Agent Name:** Emily Carter- **Phone:** 2131234567## INJURED- **Name:** Michael Johnson- **Phone:** 3101234567- **Address:** 3470 Trousdale Pkwy- **City:** Los Angeles- **State:** CA- **Zip:** 90089- **Extent of Injury:** I sustained minor injuries, including neck pain and a bruise on my left arm. I sought medical attention at the local urgent care facility.## WITNESSES- **Name:** David Thompson- **Phone:** 3105678901- **Address:** 633 W 5th St- **City:** Los Angeles- **State:** CA- **Zip:** 90071## IMPACT- **Is damaged auto essential to business?** No- **How?**
# **********************************************************************
#
# --------------------------------------------------------------------------------
# AISearchAssistant (to User):
#
# The insurance claim for the accident that happened on Sunset Blvd was filed by Michael Johnson.
#
# TERMINATE
#
# --------------------------------------------------------------------------------
